# %%
# data processing and network processing 
import pandas as pd
import networkx as nx

# plotting
import matplotlib
import matplotlib.pyplot as plt

# role extraction
from graphrole import RecursiveFeatureExtractor, RoleExtractor

# extras
import numpy as np
import seaborn as sns
import warnings
from pprint import pprint

# %%
# load the data set
data = pd.read_csv('data-triell.csv')

# %%
def create_directed_graph(df):
    g = nx.from_pandas_edgelist(df, source='username_1',
                                target='username_2',
                                create_using=nx.DiGraph())
    return g

# %%
# create retweet graph from dataframe
g = create_directed_graph(data)

# %%
g    # check graph

# %%
# create subgraph (egograph) of specific node
x = ''
def create_subgraph():
    
    # user gives twitter handle as input, egograph/subgraph of the input is created
    x = input()
    f = nx.ego_graph(g, x, undirected=True)
    
    # print information of graph
    print(nx.info(f))
    
    # plot created subgraphh
    nx.draw_networkx(f, with_labels=False, node_size=50, width=2.0,
                     node_color = ['red' if node == x else 'teal' for node in f])
    
    # print list of all nodes
    print(list(f.nodes))
    
    return f

# %% [markdown]
# ## Die Gruenen related accounts

# %%
# official account Die_Gruenen (role_0)
a = create_subgraph()
# Out:
# Die_Gruenen
# Name:
# Type: DiGraph
# Number of nodes: 96
# Number of edges: 308
# Average in degree:   3.2083
# Average out degree:   3.2083
# ['tobiaslindner', 'sixtus', 'salomon_alex', 'GruenMeyer', 'Ralf_Stegner', 'matthi_bolte', 'junomaerz', 'qadRick', 'mjoukov', 'johannes_remmel', 'SilkeGebel', 'Mary_Blumenthal', 'Marc_Urbatsch', 'bene_lux', 'cem_oezdemir', 'fdp', 'heschaus', 'platz13', 'TerryReintke', 'julia_verlinden', 'ulle_schauws', 'KlausWeckbach', 'bueti', 'K_SA', 'MiKellner', 'BriHasselmann', 'KayaKinkel', 'SebLechner', 'EckGre5', 'CLindberg_HH', 'g_reichenbach', 'JuttaPaulusRLP', 'ebner_sha', 'GruenSprecher', 'MFeldmayer', 'KathaSchulze', 'retrostyle3000', 'HansJosefBracht', 'jenny_jasberg', 'norwichruesse', 'katdro', 'Volker_Beck', 'Stefan_Birkner', 'SteveMi42686670', 'moesl_roland', 'beerenstark', 'KonstantinNotz', 'stefanziller', 'KrahMax', 'christophploss', 'sis_teract', 'HolgerEwald1', 'dunkelrotseher', 'GrueneBeate', 'CDU', 'bastianfleig', 'Engstfelder', 'peter_simone', 'topac_fatos', 'KaiGehring', 'TKinderschutz', 'FlorianPost', 'BeateWaRo', 'ChMelcher', 'JBrandenburgFDP', 'AnnaGallinaHH', 'Nicole21249915', 'AnjaSiegesmund', 'NEUMEdIER', 'andrebaumann', 'wibkegt', 'anonykatz2210', 'ClaudiaMaicher', 'WolfMalca', 'a_watch', 'DagmarHufnagel', 'bhoffmann_mdb', 'SabineBangert', 'rike_tweet', 'Die_Gruenen', 'fegebanks', 'GoeringEckardt', 'christianduerr', 'jcoetjen', 'EvaLettenbauer', 'till_steffen', 'MJatbottle', 'Oliver_Krischer', 'AfD', 'IllyricumSoul', 'AchimStrehlke', 'svenlehmann', 'carina_konrad', 'SinaDemirhan', 'StriegSe', 'DJanecek']

# %%
# Annalena Baerbock (role_0)
b = create_subgraph()
# Out:
# ABaerbock
# Name:
# Type: DiGraph
# Number of nodes: 291
# Number of edges: 902
# Average in degree:   3.0997
# Average out degree:   3.0997
# ['micha_bloss', 'LeibundgutEdith', 'ChrisKuehn_mdb', 'tobiaslindner', 'AndreasSteier', 'tjarkmelchert', 'crueffer', 'anondiver', 'GruenerDirk', 'DjirSarai', 'LauHofmann', 'Schwarz_MdB', 'MariaKlSchmeink', 'RebHarms', 'salomon_alex', 'BenBavarian', 'woelken', 'GruenMeyer', 'BerlinGestalter', 'danielakolbe', 'CimK13', 'otto_direkt', 'Ralf_Stegner', 'Tagesspiegel', 'ylvs', 'matthi_bolte', 'CBvHeusinger', 'LisaMariaOtte', 'Ricarda_Lang', 'MdB_Schmidtke', 'mjoukov', 'theresahein_', 'johannes_remmel', 'MarkusBlume', 'FrauRektorin', 'Jumpsteady', 'sinnesbichler', 'KarlFreller', 'mvabercron', 'SilkeGebel', 'Pascal_Reddig', 'SusanneHennig', 'JoswigJulian', 'Marc_Urbatsch', 'Mary_Blumenthal', 'norazabel', 'UliGroetsch', 'bene_lux', 'annachristmann', 'birmars', 'AnnaDeparnay', 'm_rinderspacher', 'cem_oezdemir', 'fbanaszak', 'PhilippGraefe', 'fdp', 'MartinRosemann', 'SteffiLemke', 'sven_kindler', 'mscharfschwerdt', 'DABornhoeft', 'jamila_anna', 'ManuelaRottman', 'hoffmannspd', 'Connylue', 'platz13', 'TerryReintke', 'Dzienus', 'KPuschmann', 'althusmann', 'ElnetD', 'noahbarkin', 'andreas_ziegert', 'julia_verlinden', 'ulle_schauws', 'IrisSpranger', 'GRUENE_Hamburg', 'ingeblask', 'bueti', 'Toens_NRW04', 'hschmidt', 'K_SA', 'MiKellner', 'BriHasselmann', 'KirstenKappert', 'samu_laade', 'Kaler_Berlin', 'KayaKinkel', 'SebLechner', 'CLindberg_HH', 'rischwasu', 'JM_Luczak', 'g_reichenbach', 'JuttaPaulusRLP', 'OpheliaNick', 'news_rapha', 'JTrittin', 'jakobblasel', 'HNeumannMEP', 'ebner_sha', 'Daniel_Sieveke', 'felixschreiner', 'AnjaKofbinger', 'GruenSprecher', 'MFeldmayer', 'berivan_aymaz', 'claasrohmeyer', 'PriskaHinz', 'KathaSchulze', 'schroeder_k', 'NadineSchoen', 'HansJosefBracht', 'RasmusAndresen', 'norwichruesse', 'jenny_jasberg', 'Sebi_Gass', 'MarcSpeicher', 'katdro', 'fbrantner', 'AlexandraGeese', 'jensspahn', 'RenateKuenast', 'TSchipanski', 'CSU', 'BauerWilli_org', 'schulzeeuropa', 'Emmanzipation', 'MatthiasHauer', 'PSchnieder', '_klimanotstand_', 'flueke', 'CarolaCypra', 'Clemens_Rostock', 'Allfor_red', 'k_ronneburg', 't0mez', 'GabrieleTriebel', 'LukasKilian', 'Stefan_Birkner', 'wahlforschung', 'DJVde', 'MarianBracht', 'AlskeFreter', 'robinhaseler', 'air_dal', 'RAinDiercks', 'moesl_roland', 'beerenstark', 'KonstantinNotz', 'GruenClaudia', 'CarolineBlarr', 'lenazagst', 'stefanziller', 'StatisticDaniel', 'akinserdara', 'christophploss', 'wegeheld', 'jonalyst', 'ABaerbock', 'OezlemADemirel', 'dunkelrotseher', 'geisenhanslueke', 'blochbihler', '_tillwe_', 'SeFischer_MEI', 'JohnLiebau', 'GrueneBeate', 'annarmpeters', 'ToRue', 'KathrinBischoff', 'Gruene_Bayern', 'Heikeschmidt', 'Hallaschka_HH', 'SteinekeCDU', 'Engstfelder', 'peter_simone', 'laurinlues', 'JanAlbrecht', 'JensZSPD', 'topac_fatos', 'alwintheobald', 'J_Zachrau', 'StefRemlinger', 'punktpreradovic', 'ctretbar', 'rosadomm_', 'lisapaus', 'KaiGehring', 'SLagodinsky', 'Mumfred67', 'Schmidtlepp', 'TKinderschutz', 'le_br0', 'margit_stumpp', 'Ehmann_Fabian', 'anunnehh', 'Marcruland', 'williehamburg', 'Schabelon', 'FlorianPost', 'GYGeorg', 'BeateWaRo', 'WilmsVal', 'HanSteinmueller', 'c_jung77', 'Kerstin_Mueller', 'bennet_mueller', 'Osgyan', 'ChMelcher', 'petra_naroska', 'Real_Eecast', 'HoffmannForest', 'AnnaGallinaHH', 'badulrichmartha', 'der_Pimon', 'Erhard_Grundl', 'AnjaSiegesmund', 'L_Petersdotter', 'MiWae21', 'andrebaumann', 'dieLinke', 'henrikMSL', 'Paritaet', 'DirkKropp', 'JasperBauer', 'wibkegt', 'mauricebmueller', 'anonykatz2210', 'philsandmann', 'Muetterforum', 'schwarzblond', 'DianaBrand19', 'GSchittek', 'themroc', 'NotkerBerlin', 'ClaudiaMaicher', 'cfuehner', 'luna_le', 'FriederikeKrick', 'KurtTaylanz', 'ststcccccc', 'JuliaKloeckner', 'EllenDemuth', 'uninformedelde1', 'gerbsen', 'ThomasHitschler', 'LJohrendt', 'HerrPhteven', 'CarstenOvens', 'SabineBangert', 'bhoffmann_mdb', 'Holger_Michel', 'DanielBornMdL', 'RwRednuloh', 'fegebanks', 'GoeringEckardt', 'MonsieurWelsch', 'agnieszka_mdb', 'AWidmannMauz', 'ninastahr', 'spdde', 'petrimv', 'EvaLettenbauer', 'till_steffen', 'ulixes24', 'Pa ...
