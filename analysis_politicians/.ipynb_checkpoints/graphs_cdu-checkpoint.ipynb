# %%
# data processing and network processing 
import pandas as pd
import networkx as nx

# plotting
import matplotlib
import matplotlib.pyplot as plt

# role extraction
from graphrole import RecursiveFeatureExtractor, RoleExtractor

# extras
import numpy as np
import seaborn as sns
import warnings
from pprint import pprint

# %%
# load the data set
data = pd.read_csv('data-triell.csv')

# %%
def create_directed_graph(df):
    g = nx.from_pandas_edgelist(df, source='username_1',
                                target='username_2',
                                create_using=nx.DiGraph())
    return g

# %%
# create retweet graph from dataframe
g = create_directed_graph(data)

# %%
g    # check graph

# %%
# create subgraph (egograph) of specific node
x = ''
def create_subgraph():
    
    # user gives twitter handle as input, egograph/subgraph of the input is created
    x = input()
    f = nx.ego_graph(g, x, undirected=True)
    
    # print information of graph
    print(nx.info(f))
    
    # plot created subgraphh
    nx.draw_networkx(f, with_labels=False, node_size=50, width=2.0,
                     node_color = ['red' if node == x else 'teal' for node in f])
    
    # print list of all nodes
    print(list(f.nodes))
    
    return f

# %% [markdown]
# ## CDU related accounts

# %%
# CDU official twitter account (role_4)
a = create_subgraph()
# Out:
# CDU
# Name:
# Type: DiGraph
# Number of nodes: 111
# Number of edges: 392
# Average in degree:   3.5315
# Average out degree:   3.5315
# ['JM_Luczak', 'JeanyLeinweber', 'menbearpigman', 'i1m81', 'jounger', 'HeyJennyLaube', 'AnnaGallinaHH', 'RKiesewetter', 'SerapGueler', 'Team_Stollberg', 'MechthildHeil', 'carina_konrad', 'peter_simone', 'CNathusius', 'ArminLaschet', 'KPuschmann', 'mvabercron', 'Hallaschka_HH', 'ChristianHirte', 'campact', 'PatriciaPeill', 'claasrohmeyer', 'JuliaKloeckner', 'arif_tasdelen', 'SilberhornMdB', '_LilliFischer', 'Die_Gruenen', 'AWidmannMauz', 'RonjaKemmer', 'MiWae21', 'bodoloettgen', 'TinoSorge', 'raymond_walk', 'PaulZiemiak', 'Heinzjean', 'MGrosseBroemer', 'GruenerWinkler', 'SwantjeMichael1', 'LieblingXhain', 'schroeder_k', 'MBiadaczMdB', 'jensspahn', 'der_Pimon', 'HansJosefBracht', 'mathiasrichel', 'till_steffen', 'DuesselSchmitz', 'heschaus', 'thorstenbenner', 'VorundNachnahme', 'TypImWald', 'bene_lux', 'spdde', 'lucies_ecke', 'BerlinGestalter', 'ebner_sha', 'CDU', 'danielakolbe', 'CarstenOvens', 'christophploss', 'TrolesHeike', 'HHirte', 'Thomas_Bareiss', 'RadtkeMdEP', 'mariovoigt', 'FKuschel', 'KlausWeckbach', 'GruenerDirk', 'frederics', 'MikeMohring', 'StefanKaufmann', 'moritzuebermuth', 'NEUMEdIER', 'AchimStrehlke', 'SeFischer_MEI', 'TSchipanski', 'DanielSzarata', 'ricogebhardt', 'SteinekeCDU', 'platz13', 'SchaalLucas', 'jcoetjen', 'witholli', 'a_watch', 'ElisabethMotsc1', 'christianduerr', 'schaefer_vgtlnd', 'JBrandenburgFDP', 'cfuehner', 'frauenunion', 'DennisGladiator', 'SLagodinsky', 'Andreas_Schwab', 'DrAndreasNick', 'Daniel_Sieveke', 'StefanGruhner', 'HeikeBrehmerMdB', 'Mary_Blumenthal', 'AndreasSteier', 'melanie74552712', 'schaefer_berlin', 'JonasUrbach', 'alwintheobald', 'MatthiasHauer', 'HNeumannMEP', 'Buehlandreas', 'MATmaschke', 'fdp', 'Stefan_Birkner', 'HolgerEwald1', 'MaikBeermann']

# %%
# Armin Laschet (role_0)
b = create_subgraph()
# Out:
# ArminLaschet
# Name:
# Type: DiGraph
# Number of nodes: 541
# Number of edges: 1222
# Average in degree:   2.2588
# Average out degree:   2.2588
