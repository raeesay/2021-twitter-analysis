# %%
# data processing and network processing 
import pandas as pd
import networkx as nx

# plotting
import matplotlib
import matplotlib.pyplot as plt

# role extraction
from graphrole import RecursiveFeatureExtractor, RoleExtractor

# extras
import numpy as np
import seaborn as sns
import warnings
from pprint import pprint

# %%
# load the data set
data = pd.read_csv('data-triell.csv')

# %%
def create_directed_graph(df):
    g = nx.from_pandas_edgelist(df, source='username_1',
                                target='username_2',
                                create_using=nx.DiGraph())
    return g

# %%
# create retweet graph from dataframe
g = create_directed_graph(data)

# %%
g    # check graph

# %%
# create subgraph (egograph) of specific node
x = ''
def create_subgraph():
    
    # user gives twitter handle as input, egograph/subgraph of the input is created
    x = input()
    f = nx.ego_graph(g, x, undirected=True)
    
    # print information of graph
    print(nx.info(f))
    
    # plot created subgraphh
    nx.draw_networkx(f, with_labels=False, node_size=200, width=2.0,
                     node_color = ['red' if node == x else 'teal' for node in f],
                     pos=nx.circular_layout(f))
    
    # print list of all nodes
    print(list(f.nodes))
    
    return f

# %% [markdown]
# ## FDP related accounts

# %%
# official account fdp (role_2)
a = create_subgraph()
# Out:
# fdp
# Name:
# Type: DiGraph
# Number of nodes: 44
# Number of edges: 152
# Average in degree:   3.4545
# Average out degree:   3.4545
# ['c_vogt', 'lofferg', 'Chris15428767', 'bjoernstritzel', 'th_sattelberger', 'JBrandenburgFDP', 'johannesvogel', 'moritzkoerner', 'konopka_p', 'OlafScholz', 'spdde', 'Meyer_FDP', 'dieLinke', 'Ricarda_Lang', 'DFoest', 'HoffmannForest', 'carina_konrad', 'christianduerr', 'reinholdmdb', 'ABaerbock', 'faxe3081', 'Die_Gruenen', 'a_watch', 'frank_thelen', 'jungeliberale', 'Otto_Fricke', 'fdp', 'qadRick', 'NowaboFM', 'UlrichSchneider', 'MarcoBuschmann', 'Stefan_Birkner', 'CDU', 'LiMiBRB', 'KlausWeckbach', 'jcoetjen', 'c_jung77', 'NEUMEdIER', 'GustavAHorn', 'ebner_sha', 'heschaus', 'KonstantinKuhle', 'AchimStrehlke', 'c_lindner']

# %%
# Christian Lindner (role_7)
b = create_subgraph()
# Out:
# c_lindner
# Name:
# Type: DiGraph
# Number of nodes: 28
# Number of edges: 61
# Average in degree:   2.1786
# Average out degree:   2.1786
# ['c_vogt', 'SusaSchneider', 'cutwindt', 'DABornhoeft', 'th_sattelberger', 'JBrandenburgFDP', 'moritzkoerner', 'konopka_p', 'thPichler', 'salomon_alex', 'carina_konrad', 'sbamueller', 'daniel_freund', 'sandra_weeser', 'frank_thelen', 'Otto_Fricke', 'MMundelein', 'fdp', 'Felidae69427721', 'florian_toncar', 'KonstantinKuhle', 'TomSchreiberMdA', 'MarcoBuschmann', 'Lambsdorff', 'c_jung77', 'OlliLuksic', 'Tobiter2', 'c_lindner']
