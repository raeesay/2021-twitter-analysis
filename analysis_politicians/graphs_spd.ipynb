# %%
# data processing and network processing 
import pandas as pd
import networkx as nx

# plotting
import matplotlib
import matplotlib.pyplot as plt

# role extraction
from graphrole import RecursiveFeatureExtractor, RoleExtractor

# extras
import numpy as np
import seaborn as sns
import warnings
from pprint import pprint

# %%
# load the data set
data = pd.read_csv('data-triell.csv')

# %%
def create_directed_graph(df):
    g = nx.from_pandas_edgelist(df, source='username_1',
                                target='username_2',
                                create_using=nx.DiGraph())
    return g

# %%
# create retweet graph from dataframe
g = create_directed_graph(data)

# %%
g    # check graph

# %%
# create subgraph (egograph) of specific node
x = ''
def create_subgraph():
    
    # user gives twitter handle as input, egograph/subgraph of the input is created
    x = input()
    f = nx.ego_graph(g, x, undirected=True)
    
    # print information of graph
    print(nx.info(f))
    
    # plot created subgraphh
    nx.draw_networkx(f, with_labels=False, node_size=50, width=2.0,
                     node_color = ['red' if node == x else 'teal' for node in f])
    
    # print list of all nodes
    print(list(f.nodes))
    
    return f

# %% [markdown]
# ## SPD related accounts

# %%
# official account SPDEurope (role_2)
a = create_subgraph()
# Out:
# SPDEuropa
# Name:
# Type: DiGraph
# Number of nodes: 8
# Number of edges: 20
# Average in degree:   2.5000
# Average out degree:   2.5000
# ['spdde', 'SPDEuropa', 'woelken', 'MariaNoichl', 'Schuster_MdEP', 'OlafScholz', 'vorwaerts', 'SPDbewegt']

# %%
# Olaf Scholz (role_0)
b = create_subgraph()
# Out:
# OlafScholz
# Name:
# Type: DiGraph
# Number of nodes: 247
# Number of edges: 808
# Average in degree:   3.2713
# Average out degree:   3.2713
# ['cfuehner', 'sebast_hartmann', 'bhoffmann_mdb', 'ursusistusus', 'HansJosefBracht', 'Tagesspiegel', 'justMPO', 'philipp_fuer_DU', 'gerbsen', 'larsklingbeil', 'K_SA', 'hschmidt', 'BoehningB', 'Sebi_Gass', 'Politischunkor2', 'CimK13', 'OlliLuksic', 'RebHarms', 'K_Rudolph_SPD', 'AlpKIRCI', 'Doro_Martin', 'SusanneHennig', 'MarcSpeicher', 'GordonSchnieder', 'CanselK', 'UliGroetsch', 'JoSteiniger', 'StefanZimkeit', 'SteinekeCDU', 'sven_kindler', 'ekindeligoez', 'Juliane_Seifert', 'fiedelseb', 'T_Ortelt', 'Fcm_BeckerSPD', 'schneidercar', 'MichaelRueter', 'LJohrendt', 'Andreas_Schwab', 'Ralf_Stegner', 'SteffenBilger', 'MuellerChemnitz', 'OpheliaNick', 'v_olberg', 'StefRemlinger', 'micha_bloss', 'arif_tasdelen', 'andreas_ziegert', 'peter_simone', 'HHirte', 'Dahlemann', 'Dennis_Buchner', 'borispistorius', 'MetinHakverdi', 'RadtkeMdEP', 'MiRo_SPD', 'MFeldmayer', 'IllyricumSoul', 'RuthMuellerSPD', 'DJVde', 'AntoniaNiecke', 'wahlforschung', 'Kaiser_SPD', 'JoergGeerlings', 'TomSchreiberMdA', 'AndreasSchulze', 'NowaboFM', 'NotkerBerlin', 'NataschaKohnen', 'FabianGramling', 'Real_Eecast', 'Stefan_Birkner', 'danielakolbe', 'hoffmannspd', 'Alex_Schweitzer', 'ingeblask', 'KlausAdelt', 'crueffer', 'fraufrerichs', 'ChristianEnxing', 'ChristianHirte', 'JTrittin', 'juergencosse', 'larscastellucci', 'stonie_kiel', 'spdde', 'melanieleonhard', 'woelken', 'Erhard_Grundl', 'ntvde_Politik', 'MatthiasHauer', 'frank_thelen', 'DirkWieseSPD', 'CDUNRW_de', 'althusmann', 'InkaGoRe', 'ilkhanipour', 'Schwarz_MdB', 'Andreas_Rimkus', 'mirko1a', 'AisheGumus', 'timo_kon', 'MonaHosseini_', 'SerpilMidyatli', 'FranziskaGiffey', 'fritzfelgentreu', 'katarinabarley', 'SebLechner', 'baerbelbas', 'OlafScholz', 'J_Zachrau', 'benniwalczak', 'PSchnieder', 'c_vogt', 'Dr_Pantazis', 'oleplambeck', 'noahbarkin', 'PaulZiemiak', 'verenahubertz', 'Christo50420237', 'SteffiLemke', 'ideeflix', 'PARTEIESSEN', 'TSchipanski', 'BarisOenes', 'CBvHeusinger', 'ManuelaSchwesig', 'CSU', 'W_Schmidt_', 'platz13', 'JM_Luczak', 'FlorianvonBrunn', 'RollandGabi', 'MdB_Schmidtke', 'SLagodinsky', 'HNeumannMEP', 'MartinRosemann', 'AWidmannMauz', 'Schabelon', 'JensZSPD', 'IsmailErtug', 'mathiasrichel', 'Krawallstein', 'jessenphil', 'SilberhornMdB', 'schroeder_k', 'brigittezypries', 'MarkusBlume', 'MGrosseBroemer', 'SteinMdL', 'kiribraun', 'AlskeFreter', 'ricardo_lerch', 'JuliaKloeckner', 'EuropaJens', 'SvenjaSchulze68', 'bennet_mueller', 'UdoBullmann', 'bene_lux', 'mjoukov', 'gabischoff', 'Daniel_Sieveke', 'PatriciaPeill', 'petrimv', 'TinoSorge', 'StefanKaufmann', 'g_reichenbach', 'Kajo2009', 'LutzLiebscher', 'bueti', 'MiWae21', 'rosadomm_', 'LangeJulian', 'DJanecek', 'BauerWilli_org', 'BetMueller', 'LukasKilian', 'Clemens_Rostock', 'vorwaerts', 'christophploss', 'SawsanChebli', 'HolgerMannLE', 'ElnetD', 'Regendelfin', 'tj_tweets', 'StefanAdamski1', 'SvenTeuber', 'Hol_Schroeder', 'Hallaschka_HH', 'joernfreynick', 'L_Petersdotter', 'F_I_Briest', 'MariaKlSchmeink', 'CarstenOvens', 'k_ronneburg', 'Marcruland', 'claasrohmeyer', 'witholli', 'Mary_Blumenthal', 'santosherrmann', 'spdhh', 'SFischer65', 'KaiGehring', 'SPDEuropa', 'FKuschel', 'ulixes24', 'MariaNoichl', 'TrolesHeike', 'hubertus_heil', 'IrisSpranger', 'dieLinke', 'martinhabersaat', 'Achim_P', 'FBrings', 'DoroBaer', 'EllenDemuth', 'ctretbar', 'FalkoMohrs', 'Dennis_Maelzer', 'KatjaMast', 'oezoguz', 'AnkeRehlinger', 'SchaalLucas', 'punktpreradovic', 'fdp', 'Paritaet', 'rischwasu', 'groehe', 'SeFischer_MEI', 'KerstinGriese', 'till_steffen', 'BerlinGestalter', 'spdberlin', 'jorg_radek', 'erik_donner', 'AnniKlose', 'Timon_Gremmels', 'kurtmfischer', 'gunnar_beck', 'MaikBeermann', 'danielasteinro1', 'JanRedmannWk', 'm_rinderspacher', 'PhilColler', 'Sabine_Baetzing', 'ebner_sha', 'pitgottschalk']
