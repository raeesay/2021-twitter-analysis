# %%
import warnings
import pandas as pd
import networkx as nx
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from pprint import pprint
from graphrole import RecursiveFeatureExtractor, RoleExtractor

# %% [markdown]
# ## Data Processing

# %%
# load the dataset
data = pd.read_csv('data-triell.csv')

# %%
data.head()
# Out:
#        username_1 username_2  timestamp_s
# 0   MetinHakverdi       Nico   1630267154
# 1        JensZSPD       Nico   1630264243
# 2        hschmidt       Nico   1630263176
# 3  MartinRosemann       Nico   1630264131
# 4    CarstenOvens       Nico   1630263327

# %%
data.shape
# Out:
# (16660, 3)

# %% [markdown]
# ## Creating Graph

# %%
def create_directed_graph(df):
    g = nx.from_pandas_edgelist(df, source='username_1',
                                target='username_2',
                                create_using=nx.DiGraph())
    return g

# %%
g = create_directed_graph(data)

# %%
g

# %% [markdown]
# ## Role Extraction

# %%
# extract features
feature_extractor = RecursiveFeatureExtractor(g)
features = feature_extractor.extract_features()

# %%
# assign node roles
role_extractor = RoleExtractor(n_roles=None)
role_extractor.extract_role_factors(features)
node_roles = role_extractor.roles

print('\nnode_roles:')
pprint(node_roles)

print('\nNode role membership by percentage:')
print(role_extractor.role_percentage.round(2))
# Out:
# node_roles:
# {'00schneemann': 'role_0',
#  '0815_goes_4711': 'role_0',
#  '0Murat0': 'role_6',
#  '0__Punkt': 'role_0',
#  '0x127001': 'role_6',
#  '100erneuerbar': 'role_0',
#  '10DMark': 'role_0',
#  '11achim71': 'role_3',
#  '123Lenchen': 'role_0',
#  '1893ituka': 'role_0',
#  '1900HO': 'role_7',
#  '1951Mann': 'role_0',
#  '1964Andreasda': 'role_0',
#  '1Klaudius62': 'role_6',
#  '1arealtalk': 'role_0',
#  '1teufelskreis': 'role_0',
#  '2008_jens': 'role_0',
#  '31O6926': 'role_5',
#  '3697elfriedel': 'role_6',
#  '4g0nm': 'role_5',
#  '558d86617a41449': 'role_4',
#  '6cks_': 'role_0',
#  '73erStrikesBack': 'role_6',
#  '7654321o': 'role_6',
#  '90sChris': 'role_7',
#  '98mercedes98': 'role_7',
#  '99Michel99': 'role_3',
#  'A1207Sa': 'role_6',
#  'ABCWorldNews': 'role_0',
#  'ABaerbock': 'role_0',
#  'ABalsliemke': 'role_3',
#  'ADressel': 'role_2',
#  'AGBuelow': 'role_0',
#  'AGH_Berlin': 'role_0',
#  'AGStadtkerne': 'role_0',
#  'AK55828631': 'role_5',
#  'AK_Meier': 'role_0',
#  'AK__Social': 'role_6',
#  'AKaiser94789344': 'role_0',
#  'ALevermann': 'role_0',
#  'AMazzeppa': 'role_6',
#  'ANiebler': 'role_0',
#  'ANiklaus4': 'role_3',
#  'APVogt': 'role_2',
#  'APatzwahl': 'role_0',
#  'ARD_BaB': 'role_0',
#  'ARD_Presse': 'role_0',
#  'ARasilop': 'role_7',
#  'ASF_SPDFrauen': 'role_0',
#  'ASTS1972': 'role_6',
#  'ATausNRW': 'role_3',
#  'AWidmannMauz': 'role_7',
#  'AXL_0711': 'role_6',
#  'A_Schillhaneck': 'role_2',
#  'AaronClamann': 'role_0',
#  'AbdelkarimsLP': 'role_0',
#  'Absurdistan123': 'role_6',
#  'Abtreibpranger': 'role_0',
#  'AceKaiser': 'role_0',
#  'AchavaFest': 'role_0',
#  'AchimKuenzel': 'role_0',
#  'AchimStrehlke': 'role_0',
#  'Achim_P': 'role_0',
#  'AdaJakobsthal': 'role_0',
#  'Adam76769590': 'role_6',
#  'AeliaVicusPlave': 'role_0',
#  'Aennti': 'role_0',
#  'AfD': 'role_0',
#  'AfDBerlin': 'role_0',
#  'AfDFraktionAGH': 'role_0',
#  'AfDLindemann': 'role_0',
#  'AfDWahlkampf': 'role_3',
#  'AfD_Bayern': 'role_0',
#  'AfD_Muenster': 'role_0',
#  'AfD_ThL': 'role_0',
#  'AfD_Thueringen': 'role_0',
#  'AfDimBundestag': 'role_0',
#  'AfDimEUParl': 'role_0',
#  'AfdLwl': 'role_0',
#  'Afelia': 'role_0',
#  'AhmadMassoud01': 'role_0',
#  'Ahmed_chalku': 'role_5',
#  'AhnSlayrJ': 'role_0',
#  'AiasMaior': 'role_0',
#  'Aimachill': 'role_0',
#  'AisheGumus': 'role_4',
#  'Akbar_offiziell': 'role_0',
#  'AkbulutGokay': 'role_0',
#  'AkiroSchiwa': 'role_0',
#  'AlBu83': 'role_6',
#  'AlHau7': 'role_3',
#  'Albatro99108219': 'role_3',
#  'Albinogiraffe1': 'role_4',
#  'AlbrechtPallas': 'role_1',
#  'AldousLeary': 'role_7',
#  'Alece92912603': 'role_7',
#  'Aledavyd': 'role_0',
#  'AleksM85806064': 'role_5',
#  'AlexCody17': 'role_4',
#  'AlexDierksMdL': 'role_0',
#  'AlexSas31040729': 'role_6',
#  'AlexTheBike': 'role_6',
#  'AlexWallasch': 'role_0',
#  'AlexWieIchBin': 'role_3',
#  'AlexZ0283': 'role_5',
#  'Alex_Schweitzer': 'role_4',
#  'Alexand36061482': 'role_7',
#  'Alexand49766375': 'role_3',
#  'Alexand95308875': 'role_0',
#  'AlexanderLasch': 'role_4',
#  'AlexandraCarl2': 'role_7',
#  'AlexandraGeese': 'role_4',
#  'Alexandra_421': 'role_0',
#  'Alexels1512': 'role_3',
#  'AlexiaP92779533': 'role_6',
#  'Alexis_de_Lalas': 'role_6',
#  'AliCologne': 'role_0',
#  'AliHeydar15': 'role_6',
#  'AliceSpatz': 'role_0',
#  'Alice_Weidel': 'role_0',
#  'Allfor_red': 'role_4',
#  'AlpKIRCI': 'role_1',
#  'AlphaTau15': 'role_4',
#  'Alpha_Rocking': 'role_0',
#  'AlpixTM': 'role_7',
#  'AlskeFreter': 'role_4',
#  'AlternativeNRW': 'role_0',
#  'Alternativlos3': 'role_3',
#  'Ambielex1': 'role_0',
#  'AmerAcadPeds': 'role_0',
#  'AmidRabieh': 'role_0',
#  'Amira_M_Ali': 'role_7',
#  'AmrullahSaleh2': 'role_0',
#  'AnInnerConflict': 'role_6',
#  'AnLa18294437': 'role_7',
#  'AnP_Magazin': 'role_4',
#  'AndDobro': 'role_6',
#  'AndersonAfDMdEP': 'role_0',
#  'AndiThorsten': 'role_6',
#  'Andi_Wagner': 'role_2',
#  'Andie_antwortet': 'role_5',
#  'AndrMey': 'role_3',
#  'AndreBeran': 'role_3',
#  'AndreaKlieve': 'role_0',
#  'AndreaPirringer': 'role_0',
#  'Andreas22181762': 'role_0',
#  'AndreasAndy3131': 'role_0',
#  'AndreasBerle': 'role_0',
#  'AndreasKemper': 'role_0',
#  'AndreasKoristka': 'role_0',
#  'AndreasPechtold': 'role_0',
#  'AndreasSchulze': 'role_3',
#  'AndreasSprecher': 'role_0',
#  'AndreasSteier': 'role_4',
#  'Andreas_Rimkus': 'role_0',
#  'Andreas_Schwab': 'role_7',
#  'AndreoWicz': 'role_1',
#  'AndreyOldSchool': 'role_6',
#  'AndyPoettgen': 'role_0',
#  'Anemalon19': 'role_7',
#  'AngiMorstadt': 'role_3',
#  'AnjaKofbinger': 'role_4',
#  'AnjaSiegesmund': 'role_4',
#  'Anja_aaaaa': 'role_7',
#  'Anjaisonline': 'role_6',
#  'AnkeHassel': 'role_0',
#  'AnkeRehlinger': 'role_2',
#  'Anna18750705': 'role_3',
#  'AnnaDeparnay': 'role_4',
#  'AnnaGallinaHH': 'role_2',
#  'AnneWillTalk': 'role_0',
#  'Annelenen1234An': 'role_0',
#  'AnniHuber': 'role_0',
#  'AnniKlose': 'role_4',
#  'AnonymousWbw': 'role_3',
#  'AnsarBerlin': 'role_0',
#  'AnserJen': 'role_0',
#  'Anstaltsleiter': 'role_2',
#  'Anterselva1': 'role_4',
#  'AntiAlternative': 'role_0',
#  'AntiHassImNetz': 'role_6',
#  'AntjeFeiks': 'role_0',
#  'AntonKonneke': 'role_0',
#  'AntoniaNiecke': 'role_0',
#  'Aras_Nathan': 'role_0',
#  'ArfstW': 'role_3',
#  'ArioMirzaie': 'role_0',
#  'Arista53692379': 'role_0',
#  'Arizona10238417': 'role_6',
#  'Ariztizbal': 'role_0',
#  'ArminLaschet': 'role_0',
#  'ArminRoennau': 'role_6',
#  'ArminWolf': 'role_0',
#  'Arndt_Klocke': 'role_0',
#  'ArneBab': 'role_7',
#  'ArnePetersen16': 'role_5',
#  'Arne_Timm_1': 'role_5',
#  'Assisi_Project': 'role_0',
#  'AstridScharf2': 'role_0',
#  'AtlanticCouncil': 'role_0',
#  'AuerTobi': 'role_6',
#  'AugusteCalami': 'role_4',
#  'AusBine': 'role_7',
#  'AusFuzzy': 'role_0',
#  'AuschwitzMuseum': 'role_0',
#  'AuswaertigesAmt': 'role_0',
#  'AutorToto': 'role_0',
#  'AutumnAlias': 'role_5',
#  'Ava__Hirsch': 'role_5',
#  'AvonacoTV': 'role_3',
#  'Axarya': 'role_0',
#  'AxelHohl': 'role_7',
#  'AzadAyd95553825': 'role_3',
#  'BAHarburg': 'role_0',
#  'BB12_DE': 'role_0',
#  'BBem87': 'role_3',
#  'BILD': 'role_2',
#  'BILD_Politik': 'role_0',
#  'BLN_CoMeCo': 'role_7',
#  'BMAS_Bund': 'role_0',
#  'BMF_Bund': 'role_0',
#  'BMG_Bund': 'role_0',
#  'BMI_Bund': 'role_0',
#  'BMVI': 'role_0',
#  'BMVg_Bundeswehr': 'role_0',
#  'BPsteinmueller': 'role_0',
#  'BQ56168714': 'role_0',
#  'BVG_Ubahn': 'role_0',
#  'BVKJ': 'role_0',
#  'BWassertisch': 'role_0',
#  'BWjetzt': 'role_0',
#  'B_Gunners21': 'role_7',
#  'Ba5el': 'role_7',
#  'BabettZapfe': 'role_3',
#  'BachmannRudi': 'role_0',
#  'Bachsonate': 'role_6',
#  'BadTrader5': 'role_3',
#  'BadrigXt': 'role_0',
#  'BaerbelHoehn': 'role_0',
#  'BaharAslan_': 'role_0',
#  'BalkonRocker': 'role_0',
#  'Banana_Joe2': 'role_3',
#  'BandtheBears1': 'role_4',
#  'Bangeline6': 'role_7',
#  'Barbara67581170': 'role_3',
#  'BarbaraKirstein': 'role_0',
#  'BarisOenes': 'role_0',
#  'Bart1893': 'role_6',
#  'BastiGassl': 'role_3',
#  'BastianBrauns': 'role_0',
#  'Battefeld5': 'role_0',
#  'Bauchkribbeln2': 'role_3',
#  'BauerWilli_org': 'role_3',
#  'Baumpilot1': 'role_0',
#  'BavariaGangsta': 'role_3',
#  'BayernSPD': 'role_0',
#  'BayernSPD_Lndtg': 'role_0',
#  'BayernSyberella': 'role_3',
#  'BeGoodDe': 'role_0',
#  'BeSondererBlick': 'role_3',
#  'BeatePohl2': 'role_6',
#  'BeateWaRo': 'role_4',
#  'Beatriceroduner': 'role_0',
#  'Beatrix_vStorch': 'role_0',
#  'Becker_uk': 'role_0',
#  'Bee87032600': 'role_6',
#  'BeesAndHoney123': 'role_3',
#  'Behindt93065949': 'role_0',
#  'BehrischGeorge': 'role_6',
#  'BenBavarian': 'role_0',
#  'BenHope1981': 'role_3',
#  'BenJongo': 'role_6',
#  'BenWeinthal': 'role_0',
#  'Beneoster': 'role_4',
#  'BenjaminDThomas': 'role_0',
#  'BenjaminHeese': 'role_0',
#  'BenjaminHoff': 'role_0',
#  'BenniAps': 'role_0',
#  'Bennix1308': 'role_7',
#  'BentFreiwald': 'role_0',
#  'Beobach05788281': 'role_1',
#  'Beobach05943803': 'role_0',
#  'Berater_1': 'role_3',
#  'BerlinDentis1': 'role_0',
#  'BerlinElias': 'role_0',
#  'BerlinGestalter': 'role_2',
#  'BerlinGross': 'role_6',
#  'BerlinerNord': 'role_1',
#  'BerlinerNotizen': 'role_0',
#  'Berliner_JA': 'role_0',
#  'Bernd07037046': 'role_6',
#  'BernhardBraunLT': 'role_1',
#  'BernhardHinsken': 'role_3',
#  'BernhardZimniok': 'role_0',
#  'BernieHoffi': 'role_0',
#  'BertHagels': 'role_0',
#  'BertvanBurgh2': 'role_0',
#  'BetMueller': 'role_2',
#  'BetienneA': 'role_3',
#  'Betigoeshappy': 'role_0',
#  'Betti44918354': 'role_3',
#  'Bettina58130936': 'role_7',
#  'BettinaBender5': 'role_5',
#  'BettinaHornhues': 'role_4',
#  'BettinaSRoss1': 'role_0',
#  'Bettina_Jarasch': 'role_0',
#  'Bettitogo': 'role_1',
#  'BharoNarendra': 'role_6',
#  'BiJour': 'role_4',
#  'Bielefelder1905': 'role_0',
#  'BildungslandNRW': 'role_0',
#  'Bilgard2': 'role_6',
#  'BillBramhall': 'role_0',
#  'BillyJ147': 'role_0',
#  'BimboBeau': 'role_6',
#  'Bin_privat_hier': 'role_0',
#  'Bine692': 'role_3',
#  'BineB': 'role_2',
#  'BineWe2': 'role_0',
#  'BioSchwan': 'role_0',
#  'Birgit_Kelle': 'role_0',
#  'Birnstab': 'role_0',
#  'BitcoinIsKingg': 'role_5',
#  'BjoernRaven': 'role_6',
#  'BjoernSimon': 'role_0',
#  'BjoernThoroe': 'role_4',
#  'Bjoern_Ziemann': 'role_6',
#  'BjornHarras': 'role_4',
#  'Blancko': 'role_0',
#  'BlickpunktASM': 'role_0',
#  'Blue_eyes_2021': 'role_0',
#  'BluhmRobert': 'role_1',
#  'BlumeEvolution': 'role_0',
#  'Bo75298337': 'role_6',
#  'BobKelzow': 'role_7',
#  'Bode_Anne1': 'role_7',
#  'BodoNoeske': 'role_0',
#  'BodoZenner': 'role_6',
#  'BoehningB': 'role_7',
#  'BohneDen': 'role_6',
#  'BolligGreta': 'role_0',
#  'Boris20537': 'role_6',
#  'Bortanos': 'role_0',
#  'BosscherDennis': 'role_6',
#  'Brainflakes': 'role_6',
#  'BrandThomas': 'role_3',
#  'Braun2Joerg': 'role_3',
#  'BreuerLeopold': 'role_7',
#  'BriHasselmann': 'role_4',
#  'BrightLight75': 'role_6',
#  'BrinkmannLab': 'role_0',
#  'BrodnikB': 'role_6',
#  'BruceWayyyne': 'role_0',
#  'Brummelbr1': 'role_0',
#  'BrunettiGi': 'role_7',
#  'Bruno76921911': 'role_5',
#  'BuNiRiDienst': 'role_3',
#  'BuchheitMarkus': 'role_0',
#  'Buchiworldwide': 'role_6',
#  'Buckenhofer': 'role_0',
#  'Buehlandreas': 'role_2',
#  'BuettnerAndreas': 'role_0',
#  'BuiltResist': 'role_6',
#  'Burger65847255': 'role_0',
#  'BurkertEulitz': 'role_2',
#  'BuschRiecke': 'role_6',
#  'BusseTanja': 'role_0',
#  'Buster_InShorts': 'role_5',
#  'Butterblmchen3': 'role_3',
#  'Bw_Einsatz': 'role_0',
#  'ByggvirOfBarley': 'role_6',
#  'BytestarX': 'role_3',
#  'CBvHeusinger': 'role_4',
#  'CCPlayer3D': 'role_1',
#  'CDEDeMuynck': 'role_6',
#  'CDU': 'role_4',
#  'CDUNRW_de': 'role_3',
#  'CDU_BW': 'role_0',
#  'CDU_KV_PB': 'role_0',
#  'CKross36': 'role_7',
#  'CLindberg_HH': 'role_0',
#  'CMller3': 'role_7',
#  'CNathusius': 'role_1',
#  'COMPACTMagazin': 'role_0',
#  'COberhaupt': 'role_0',
#  'CPPLUCINSKI': 'role_6',
#  'CP_Berlin': 'role_0',
#  'CSDdresden': 'role_0',
#  'CSU': 'role_4',
#  'CTrettler': 'role_0',
#  'C_Holler': 'role_0',
#  'C_Pohlmann': 'role_6',
#  'C_Sterzik': 'role_0',
#  'Caligul74126875': 'role_6',
#  'CamPeter6': 'role_0',
#  'Camistra3': 'role_6',
#  'CanselK': 'role_4',
#  'Cardiesel2': 'role_7',
#  'CarloMasala1': 'role_0',
#  'CarolaCypra': 'role_2',
#  'CarolaSch__': 'role_0',
#  'CarolinHelmecke': 'role_0',
#  'CarolineBlarr': 'role_0',
#  'CarstenBrosda': 'role_0',
#  'CarstenLoo': 'role_1',
#  'CarstenOvens': 'role_4',
#  'Case_IH': 'role_0',
#  'CedricGapinski': 'role_6',
#  'Cerisella1': 'role_6',
#  'CerstinGammelin': 'role_0',
#  'Cfa_2019': 'role_1',
#  'ChHolzemer': 'role_0',
#  'ChMelcher': 'role_0',
#  'ChanasitJonas': 'role_0',
#  'CheekyBoinc': 'role_0',
#  'Cherie7799': 'role_2',
#  'ChibiZerberus': 'role_6',
#  'Chickenwing64': 'role_0',
#  'ChiefTenzing': 'role_6',
#  'China_Welt_News': 'role_0',
#  'ChipotleChipot3': 'role_6',
#  'Chlodwig14': 'role_0',
#  'Choleria': 'role_6',
#  'Chr1Chris': 'role_0',
#  'ChrDorner': 'role_1',
#  'Chris12293323': 'role_3',
#  'Chris15428767': 'role_1',
#  'Chris32770312': 'role_7',
#  'ChrisCldtz': 'role_0',
#  'ChrisDuCoeur': 'role_3',
#  'ChrisKuehn_mdb': 'role_4',
#  'ChrisPos11': 'role_6',
#  'ChrisStoecker': 'role_0',
#  'Chris__Tus': 'role_7',
#  'Chrissi19484446': 'role_5',
#  'Christi43738671': 'role_7',
#  'Christi61278506': 'role_0',
#  'Christi73377364': 'role_6',
#  'ChristianDeut17': 'role_7',
#  'ChristianEnxing': 'role_4',
#  'ChristianHelms': 'role_0',
#  'ChristianHirte': 'role_2',
#  'ChristianK_C': 'role_6',
#  'ChristianKlink4': 'role_3',
#  'ChristianWeyer4': 'role_0',
#  'Christian_FFM91': 'role_0',
#  'Christian_Henne': 'role_0',
#  'Christiane': 'role_0',
#  'ChristinIsa': 'role_6',
#  'ChristineClivot': 'role_0',
#  'Christo50420237': 'role_3',
#  'ChristophMerk': 'role_0',
#  'ChrizKu': 'role_7',
#  'Chukcha20561785': 'role_0',
#  'CimK13': 'role_3',
#  'CiskoNokia': 'role_0',
#  'Cl_Engelberts': 'role_6',
#  'Claas100': 'role_3',
#  'Clannad992': 'role_6',
#  'Claro17020026': 'role_6',
#  'Claudia2795': 'role_7',
#  'Claudia55720332': 'role_4',
#  'ClaudiaHagan2': 'role_1',
#  'ClaudiaMaicher': 'role_0',
#  'Claudiusseidl': 'role_0',
#  'Clauduella_ella': 'role_0',
#  'ClausKleber': 'role_0',
#  'ClausSchaffer': 'role_6',
#  'ClausStrunz': 'role_0',
#  'ClemensLeathley': 'role_7',
#  'ClemensLechner': 'role_0',
#  'Clemens_Rostock': 'role_3',
#  'CleoCatharina': 'role_3',
#  'Co19711': 'role_6',
#  'Cochiban': 'role_7',
#  'CoinOperatedBoy': 'role_1',
#  'Combat5288': 'role_6',
#  'ComedianFactory': 'role_0',
#  'CommanderROR9': 'role_5',
#  'Conni_Moehring': 'role_7',
#  'ConnyR0mer': 'role_7',
#  'Connylue': 'role_4',
#  'Const99102': 'role_7',
#  'ContentHistory': 'role_0',
#  'CoonKlara': 'role_6',
#  'CordMeier1': 'role_0',
#  'CorneliusRoemer': 'role_0',
#  'Cornwel89470426': 'role_6',
#  'CorvinKochan': 'role_0',
#  'Cosina_Wolf': 'role_0',
#  'Coskun02438757': 'role_3',
#  'CowgirlGermany': 'role_0',
#  'CptOhm': 'role_6',
#  'Crimnic1': 'role_1',
#  'CronMax': 'role_6',
#  'Crosis19871987': 'role_0',
#  'CthulhuLivesOn': 'role_3',
#  'CuratPraetor': 'role_0',
#  'Czech_MdHB': 'role_0',
#  'CzypionkaThomas': 'role_0',
#  'D3419A68': 'role_6',
#  'DABornhoeft': 'role_4',
#  'DASdemo': 'role_6',
#  'DB_Bahn': 'role_0',
#  'DCStudiosProd': 'role_3',
#  'DCipriano83': 'role_0',
#  'DEZi_Brb': 'role_0',
#  'DFoest': 'role_0',
#  'DGKJ_eV': 'role_0',
#  'DGPIeV': 'role_0',
#  'DGoncz': 'role_0',
#  'DIELINKEHESSEN': 'role_0',
#  'DIELINKE_VS': 'role_0',
#  'DIE_LINKE_Do': 'role_0',
#  'DIE_LINKE_MV': 'role_0',
#  'DJVde': 'role_3',
#  'DJanecek': 'role_2',
#  'DLF_Sport': 'role_0',
#  'DR3638': 'role_6',
#  'DSM_Nordkirche': 'role_0',
#  'DTurrican8': 'role_2',
#  'DWD_presse': 'role_0',
#  'DWN_de': 'role_0',
#  'D_Herrmann': 'role_0',
#  'D_Stich': 'role_0',
#  'D_W_I_L_L_L_L_L': 'role_6',
#  'DaSmellcaster': 'role_0',
#  'Dachsberg': 'role_3',
#  'DagmarFreitag13': 'role_0',
#  'DagmarGleitz': 'role_0',
#  'DagmarHufnagel': 'role_0',
#  'Dahlemann': 'role_0',
#  'DaniLudwigMdB': 'role_0',
#  'Daniel49982548': 'role_6',
#  'DanielBornMdL': 'role_0',
#  'DanielDBoehmer': 'role_0',
#  'DanielHaseloff': 'role_0',
#  'DanielSteinrode': 'role_0',
#  'DanielSzarata': 'role_4',
#  'Daniel_Roetzer': 'role_0',
#  'Daniel_Sieveke': 'role_2',
#  'DanielaHohmann': 'role_0',
#  'DanielaHuetter': 'role_7',
#  'DanielaKluckert': 'role_0',
#  'Daniele95206428': 'role_7',
#  'DanieleGanser': 'role_0',
#  'Dannimaus_': 'role_0',
#  'Daphne_Web': 'role_0',
#  'Darijouu': 'role_6',
#  'DarioPower': 'role_7',
#  'DarthHesse': 'role_0',
#  'DasErste': 'role_0',
#  'DasSteven': 'role_1',
#  'Dav_Pas': 'role_3',
#  'DavidCBrooks96': 'role_0',
#  'DavidMuir': 'role_0',
#  'DavidZza': 'role_0',
#  'David_haMelekh1': 'role_6',
#  'Davvero_Nessuno': 'role_3',
#  'DeRhoihesse': 'role_1',
#  'DeThoma59680777': 'role_0',
#  'Dealman88907136': 'role_3',
#  'DegowskiI': 'role_1',
#  'Deichi72': 'role_1',
#  'DeineTour': 'role_0',
#  'Deliandelicious': 'role_7',
#  'Demetrio_Sca': 'role_7',
#  'DemoKinderarmut': 'role_0',
#  'DennisGladiator': 'role_7',
#  'DennisKBerlin': 'role_0',
#  'Dennis_Buchner': 'role_3',
#  'Dennis_Hohloch': 'role_0',
#  'Dennis_Maelzer': 'role_4',
#  'Denny_Jankowski': 'role_0',
#  'DerAlex4711': 'role_6',
#  'DerBahnfrosch': 'role_0',
#  'DerDanyal': 'role_0',
#  'DerDrPappa': 'role_0',
#  'DerGraslutscher': 'role_0',
#  'DerHirnfurz': 'role_3',
#  'DerInformant_': 'role_0',
#  'DerJanChristoph': 'role_0',
#  'DerKinderarzt': 'role_7',
#  'DerLachmann': 'role_0',
#  'DerNarkotiseur': 'role_0',
#  'DerOetzmann': 'role_1',
#  'DerPrivatlehrer': 'role_7',
#  'DerRechteAnwalt': 'role_0',
#  'DerSchaender003': 'role_6',
#  'DerSynodaleWeg': 'role_0',
#  'Der_BDI': 'role_0',
#  'Der_Bjoerni': 'role_7',
#  'Der_Postillon': 'role_0',
#  'Der_ToasterGmbh': 'role_7',
#  'Dericik76': 'role_7',
#  'DesUnderscores': 'role_0',
#  'Des_Roin': 'role_0',
#  'DetzerDaniel': 'role_0',
#  'DeutscheWelle': 'role_0',
#  'Deutsches_Heer': 'role_0',
#  'DexV1510': 'role_6',
#  'DianaBrand19': 'role_3',
#  'Dianaownz100': 'role_3',
#  'DiePARTEI': 'role_0',
#  'DieVielen': 'role_0',
#  'Die_Diktatur': 'role_0',
#  'Die_Gruenen': 'role_0',
#  'Die__Engel': 'role_0',
#  'DienstbierDr': 'role_6',
#  'DieterHangmar': 'role_5',
#  'DieterPrick': 'role_7',
#  'DieterichMatt': 'role_0',
#  'DietmarBartsch': 'role_4',
#  'DietmarGaisenk1': 'role_0',
#  'DietmarHeger': 'role_0',
#  'DietmarK6': 'role_6',
#  'DietmarPanske': 'role_1',
#  'DietsQ': 'role_3',
#  'Dina14083791': 'role_6',
#  'DirkGernhardt': 'role_1',
#  'DirkKropp': 'role_4',
#  'DirkSchafmeist1': 'role_3',
#  'DirkWieseSPD': 'role_4',
#  'Dirk_Thoerner': 'role_0',
#  'Dirksen34932752': 'role_6',
#  'DiscofuxRecords': 'role_3',
#  'DjirSarai': 'role_3',
#  'Doblerin': 'role_0',
#  'DocNrw': 'role_6',
#  'DoeSpam': 'role_7',
#  'DoktorDude': 'role_3',
#  'Dom_Lehmann': 'role_0',
#  'DominicMuenster': 'role_5',
#  'DominikErnst': 'role_6',
#  'DonnaCamilla8': 'role_0',
#  'DoppelkopfA': 'role_0',
#  'Doreen82047698': 'role_3',
#  'Dorfblume1': 'role_7',
#  'Dorianlynskey': 'role_0',
#  'DorisA80009661': 'role_6',
#  'DorisAchelwilm': 'role_2',
#  'DoroBaer': 'role_3',
#  'Doro_Martin': 'role_1',
#  'DorotheedeNeve': 'role_3',
#  'DrAndreasNick': 'role_3',
#  'DrCatlicious': 'role_7',
#  'DrDavidBerger': 'role_0',
#  'DrDrAlexanderW1': 'role_6',
#  'DrEricDing': 'role_0',
#  'DrFabianHorn1': 'role_0',
#  'DrHanisch': 'role_7',
#  'DrKissler': 'role_0',
#  'DrManetti': 'role_0',
#  'DrPuerner': 'role_0',
#  'DrTurgutAltug': 'role_0',
#  'DrUweSchmidt1': 'role_6',
#  'Dr_Emergencydoc': 'role_0',
#  'Dr_Konservativ': 'role_0',
#  'Dr_Pantazis': 'role_3',
#  'DuesselSchmitz': 'role_1',
#  'DustinMiesfeld': 'role_3',
#  'DutchS66': 'role_3',
#  'Dzienus': 'role_0',
#  'ECMOKaragianni1': 'role_0',
#  'EEffektiv': 'role_4',
#  'EGermroth': 'role_0',
#  'EKositza': 'role_0',
#  'ENYA42771525': 'role_0',
#  'EUCourtPress': 'role_0',
#  'EUParl_EN': 'role_0',
#  'EbenbergerStock': 'role_3',
#  'EckGre5': 'role_0',
#  'EckerleIsabella': 'role_0',
#  'Economicus': 'role_2',
#  'Eddy_Bernayz': 'role_0',
#  'EdithaSan1': 'role_0',
#  'EenSchaap': 'role_0',
#  'EgonFischer3': 'role_0',
#  'Ehmann_Fabian': 'role_0',
#  'EichholtzAlex': 'role_0',
#  'EinAugenschmaus': 'role_0',
#  'Einzelfallinfos': 'role_0',
#  'EisErnst': 'role_6',
#  'EisenhutIsidora': 'role_1',
#  'El_KaWeh_': 'role_0',
#  'ElfiElfe': 'role_0',
#  'ElfiMuhling': 'role_4',
#  'ElisabethKaleko': 'role_7',
#  'ElisabethMotsc1': 'role_4',
#  'Elisabeth_Kula': 'role_0',
#  'ElkeRic65435411': 'role_6',
#  'EllenDemuth': 'role_4',
#  'ElnetD': 'role_3',
#  'Emmanzipation': 'role_0',
#  'Engel_Re': 'role_0',
#  'EnginEroglu_FW': 'role_0',
#  'England49377044': 'role_3',
#  'Engstfelder': 'role_4',
#  'Enibas55205204': 'role_0',
#  'EnkelErich': 'role_7',
#  'EnnoSachsen': 'role_0',
#  'EnricoPomsel': 'role_3',
#  'Er1ct1on': 'role_3',
#  'ErdSa46': 'role_5',
#  'Erde2077': 'role_3',
#  'ErhardScherfer': 'role_0',
#  'Erhard_Grundl': 'role_4',
#  'Eric_mit_C': 'role_7',
#  'ErikMarquardt': 'role_0',
#  'ErikV47108766': 'role_6',
#  'ErnoeMarianne': 'role_5',
#  'ErnstSchulz1': 'role_0',
#  'Ernsthaft22': 'role_0',
#  'ErsanMondtag': 'role_0',
#  'Erwin24946838': 'role_7',
#  'Erwin49711423': 'role_6',
#  'ErwinLindeman20': 'role_3',
#  'ErzengelHeiner': 'role_0',
#  'Es17eban': 'role_5',
#  'Eschentharrn': 'role_0',
#  'EskenSaskia': 'role_2',
#  'Estee77680659': 'role_7',
#  'EsthiPesthi': 'role_4',
#  'Eure_LeylaBilge': 'role_0',
#  'EuropaJens': 'role_0',
#  'EuropaUnionDE': 'role_0',
#  'Europas_Seele': 'role_6',
#  'EvAkaRhein': 'role_0',
#  'EvAna3388': 'role_7',
#  'Eva0112': 'role_7',
#  'Eva23530871': 'role_6',
#  'EvaHoegl': 'role_0',
#  'EvaLettenbauer': 'role_3',
#  'EvaMariePlonske': 'role_0',
#  'EvaQuadbeck': 'role_0',
#  'FAZ_NET': 'role_0',
#  'FAZ_Politik': 'role_0',
#  'FBrings': 'role_1',
#  'FCKlinki': 'role_0',
#  'FCMtraue1965': 'role_6',
#  'FDPFraktionNRW': 'role_0',
#  'FDP_LSA': 'role_0',
#  'FDP_MD': 'role_0',
#  'FHackenbruch': 'role_4',
#  'FJKauder': 'role_0',
#  'FKuschel': 'role_7',
#  'FNFreiheit': 'role_0',
#  'FOhnetuch': 'role_0',
#  'FReichert667': 'role_7',
#  'FWHessen': 'role_0',
#  'F_I_Briest': 'role_0',
#  'FabianGramling': 'role_4',
#  'FabianT33029154': 'role_6',
#  'FabioDeMasi': 'role_2',
#  'Facebook': 'role_0',
#  'FalkHiepler': 'role_6',
#  'FalkoMohrs': 'role_0',
#  'FamUnt': 'role_0',
#  'Fayalit': 'role_6',
#  'Fazer_DDorf': 'role_3',
#  'Fcm_BeckerSPD': 'role_4',
#  'FcpCrypto': 'role_1',
#  'Feine16': 'role_0',
#  'Feldrain': 'role_2',
#  'Felicitatem': 'role_0',
#  'Felicos5': 'role_6',
#  'Felidae69427721': 'role_0',
#  'FelixRamberg': 'role_0',
#  'FelixSchonne': 'role_0',
#  'FellerCarsten': 'role_0',
#  'Feluxxe': 'role_6',
#  'FemmeBanale': 'role_6',
#  'Fichtl8': 'role_3',
#  'FirstGreenWave1': 'role_7',
#  'Fixi_schnell': 'role_3',
#  'FlD94': 'role_0',
#  'FlightRadar9': 'role_3',
#  'FloMotionMS': 'role_0',
#  'Flodine3': 'role_7',
#  'Florian59528055': 'role_0',
#  'FlorianHettig': 'role_0',
#  'FlorianPost': 'role_0',
#  'FlorianReiter_': 'role_0',
#  'FlorianvonBrunn': 'role_0',
#  'Floris416': 'role_6',
#  'Flychris881': 'role_1',
#  'Flying__Doc': 'role_0',
#  'Foelzchen': 'role_1',
#  'FonsoMaroni': 'role_3',
#  'FoooBarBazz': 'role_7',
#  'Ford2806': 'role_6',
#  'Forensic36': 'role_6',
#  'ForumMunchen': 'role_0',
#  'FotoHeinz': 'role_0',
#  'Fottigraf': 'role_0',
#  'FourtySixBy2': 'role_6',
#  'FrStraetmanns': 'role_0',
#  'Fragemich1': 'role_0',
#  'Fragender3': 'role_3',
#  'FraktionGruenBW': 'role_0',
#  'Frank15695762': 'role_5',
#  'Frank41856301': 'role_5',
#  'Frank97078738': 'role_7',
#  'FrankFraaank': 'role_1',
#  'FrankHansel': 'role_0',
#  'FrankKlarname': 'role_0',
#  'FrankMarx15': 'role_6',
#  'FrankSchwabe': 'role_0',
#  'FrankVo19': 'role_0',
#  'FrankWeidner2': 'role_3',
#  'Frank_Pasemann': 'role_0',
#  'Frank_vd_Valk': 'role_0',
#  'FrankieLix2020': 'role_0',
#  'FranzBranntwe10': 'role_0',
#  'FranzW99667018': 'role_0',
#  'FranziskaGiffey': 'role_2',
#  'FranziskaOL': 'role_0',
#  'FranzrebKlaus': 'role_3',
#  'FrauAuge': 'role_0',
#  'FrauBrunke': 'role_1',
#  'FrauDrAntiviral': 'role_7',
#  'FrauHonig1': 'role_3',
#  'FrauKibbeling': 'role_6',
#  'FrauKugel': 'role_3',
#  'FrauKulli': 'role_0',
#  'FrauLalu': 'role_7',
#  'FrauLavendel': 'role_0',
#  'FrauRektorin': 'role_0',
#  'FrauT18': 'role_6',
#  'Frau_Hoffnung': 'role_0',
#  'Frau_Holaczek': 'role_6',
#  'Frau_Motz': 'role_4',
#  'Frauke22210739': 'role_3',
#  'FraukeLudowig1': 'role_0',
#  'FredFlinkstone': 'role_7',
#  'Freddy2805': 'role_0',
#  'FreddySinalco': 'role_3',
#  'Freddyasdf1': 'role_0',
#  'FreedomFire17': 'role_3',
#  'FreieHeimat': 'role_0',
#  'Fresenjong': 'role_4',
#  'Freud4A': 'role_3',
#  'FreyaMoonbow': 'role_0',
#  'FridayForFuture': 'role_0',
#  'FriederikeKrick': 'role_4',
#  'Friedri23257098': 'role_6',
#  'Friesendom': 'role_0',
#  'Frisobotter': 'role_0',
#  'FritzKuhn1': 'role_0',
#  'FritzWa96008231': 'role_6',
#  'Fritzpaul60': 'role_3',
#  'FrohlingJeremy': 'role_0',
#  'Froschknig14': 'role_3',
#  'Fuchsbau_22': 'role_0',
#  'FussballFalk': 'role_6',
#  'GBundespolizei': 'role_0',
#  'GFelbermayr': 'role_0',
#  'GJusier': 'role_6',
#  'GKlamt54': 'role_0',
#  'GRUENE_CB_SPN': 'role_0',
#  'GRUENE_Hamburg': 'role_0',
#  'GRUENE_Harburg': 'role_0',
#  'GSchittek': 'role_4',
#  'GUCCI210582': 'role_3',
#  'GYGeorg': 'role_4',
#  'GabrieleFichtn1': 'role_3',
#  'GabrieleTpfr': 'role_0',
#  'GabrieleTriebel': 'role_4',
#  'GabrieleUhlmann': 'role_0',
#  'Galactica_1002': 'role_0',
#  'GalleryWhitte': 'role_0',
#  'GamonMichael': 'role_1',
#  'GanserIsabell': 'role_6',
#  'Gastrobo': 'role_0',
#  'GayTip': 'role_4',
#  'Gebauer_CDU': 'role_0',
#  'Gefuehlsbahnhof': 'role_5',
#  'GegenKinderehen': 'role_0',
#  'Gegenwind3': 'role_6',
#  'Geissenpeter191': 'role_3',
#  'Genderbeitrag': 'role_0',
#  'GeorgWelling': 'role_3',
#  'Georg_kj': 'role_0',
#  'GeraldGrosz': 'role_0',
#  'GerdMannesAfD': 'role_4',
#  'Gerhard49069597': 'role_6',
#  'GerhardRHuf': 'role_7',
#  'GerhardRichte16': 'role_0',
#  'GerhardRiewe': 'role_0',
#  'Germane77': 'role_0',
#  'GermanusHeiko': 'role_0',
#  'GesaCTeichert': 'role_4',
#  'GeyerSteven': 'role_0',
#  'Ghjizvbfdtgbb': 'role_6',
#  'GiSchenk': 'role_0',
#  'Gigolo_71': 'role_4',
#  'GildaSahebi': 'role_0',
#  'Giliell': 'role_6',
#  'Ginger_Zee': 'role_0',
#  'Girofox1': 'role_3',
#  'Gisa723': 'role_6',
#  'GiverSteve': 'role_7',
#  'GlenGra51946620': 'role_3',
#  'GlobalistYT': 'role_0',
#  'GntherWettlauf2': 'role_4',
#  'Gntr90051867': 'role_0',
#  'GoeringEckardt': 'role_4',
#  'Goldmar81983101': 'role_6',
#  'GollwitzMartin': 'role_6',
#  'GordonPfaff': 'role_0',
#  'GordonSchnieder': 'role_4',
#  'Gorgobert3': 'role_6',
#  'GorillasWorkers': 'role_0',
#  'Gothweet': 'role_0',
#  'GottfriedCurio': 'role_0',
#  'GottiSlow': 'role_0',
#  'Grabitz888': 'role_0',
#  'Graf_Fencheltee': 'role_0',
#  'Green_Europe': 'role_0',
#  'GregorGysi': 'role_0',
#  'GregorKeuschnig': 'role_6',
#  'GroKarl': 'role_5',
#  'GruebelMdb': 'role_0',
#  'GruenClaudia': 'role_2',
#  'GruenMeyer': 'role_4',
#  'GruenSprecher': 'role_0',
#  'GruenWolf': 'role_0',
#  'GrueneBW': 'role_0',
#  'GrueneBeate': 'role_4',
#  'GrueneBundestag': 'role_0',
#  'GrueneEimsbusch': 'role_2',
#  'GrueneFrakNRW': 'role_0',
#  'GrueneFraktionB': 'role_0',
#  'GrueneIngelheim': 'role_0',
#  'GruenePankow': 'role_0',
#  'GrueneTS': 'role_0',
#  'GrueneXhain': 'role_0',
#  'Gruene_Bayern': 'role_0',
#  'Gruene_Muenchen': 'role_0',
#  'Gruene_TH': 'role_0',
#  'GruenerDirk': 'role_4',
#  'GruenerWinkler': 'role_4',
#  'Grund_gesetzt': 'role_0',
#  'GrupeStefanie': 'role_1',
#  'GrutterStephan': 'role_3',
#  'GtzFrmming': 'role_0',
#  'GuentherJauch65': 'role_0',
#  'Guggi46': 'role_3',
#  'GuidoReil': 'role_0',
#  'GunnarKaiser': 'role_0',
#  'GunterDressler': 'role_6',
#  'GuseMarcus': 'role_1',
#  'GustavAHorn': 'role_1',
#  'GvB1480': 'role_7',
#  'GvStG_x_y_z': 'role_4',
#  'HBahnmuller64': 'role_7',
#  'HC61871164': 'role_6',
#  'HDFSpringerP': 'role_0',
#  'HEICKEEEE': 'role_0',
#  'HEIMERImmo': 'role_5',
#  'HESommer': 'role_4',
#  'HGMaassen': 'role_0',
#  'HHirte': 'role_2',
#  'HHumorlos': 'role_0',
#  'HKonigseder': 'role_0',
#  'HL1315185597': 'role_3',
#  'HMonhof': 'role_6',
#  'HN19754': 'role_1',
#  'HNeumannMEP': 'role_4',
#  'HPGnther1': 'role_0',
#  'HSP_NLP': 'role_0',
#  'HadlerLa': 'role_6',
#  'Haiepaul': 'role_6',
#  'Halina_Waw': 'role_0',
#  'Hallaschka_HH': 'role_2',
#  'HalleVerkehrt': 'role_0',
#  'HanSteinmueller': 'role_0',
#  'HannaBertini': 'role_6',
#  'HannaSchfer3': 'role_7',
#  'HannahLupper': 'role_0',
#  'HanneNagel1': 'role_7',
#  'Hans41345579': 'role_6',
#  'Hans456789': 'role_0',
#  'HansGrtner4': 'role_6',
#  'HansJosefBracht': 'role_2',
#  'HansRudiSulze': 'role_6',
#  'HanseMitR': 'role_0',
#  'HaraldWolf20': 'role_4',
#  'Harryy03': 'role_6',
#  'Harschunterwegs': 'role_0',
#  'Hartes_Geld': 'role_0',
#  'Hartmut73': 'role_0',
#  'HartwigCallsen': 'role_0',
#  'HarvestWrwww': 'role_6',
#  'Harzerkas': 'role_4',
#  'HausmannGerd': 'role_6',
#  'HausnerPhilly': 'role_7',
#  'HePh99': 'role_3',
#  'HeckerKarl': 'role_3',
#  'Hefeweizen': 'role_0',
#  'Heike57618965': 'role_6',
#  'HeikeBrehmerMdB': 'role_4',
#  'HeikeHaensel': 'role_0',
#  'HeikeWernerTH': 'role_0',
#  'Heikeschmidt': 'role_0',
#  'HeikoEpperlein': 'role_0',
#  'HeikoHuettel': 'role_1',
#  'HeikoMaas': 'role_0',
#  'HeikoMelzer': 'role_0',
#  'Heini37161441': 'role_0',
#  'Heinz02174585': 'role_0',
#  'Heinzjean': 'role_7',
#  'HelenDonath': 'role_0',
#  'HelenainPerlach': 'role_0',
#  'HelgaTruepel': 'role_4',
#  'HelgeBruhn': 'role_3',
#  'Helliotr': 'role_2',
#  'HendrikSchmitz': 'role_4',
#  'HendrikSmock': 'role_0',
#  'HendrikjeKlein': 'role_0',
#  'Henrik_Ru': 'role_0',
#  'Henry53246076': 'role_3',
#  'HerbrandMarkus': 'role_0',
#  'Heribert_Pilch': 'role_3',
#  'Hermannsland1': 'role_7',
#  'HerrDangi': 'role_6',
#  'HerrPhteven': 'role_0',
#  'HerrSchmitzausK': 'role_5',
#  'HerrVikarin': 'role_2',
#  'Herr_Kaleun': 'role_0',
#  'HeyJennyLaube': 'role_2',
#  'HhYaus': 'role_7',
#  'HieristLucas': 'role_0',
#  'Hightower19631': 'role_0',
#  'Hikity': 'role_3',
#  'HitOllga': 'role_7',
#  'HofDie': 'role_3',
#  'HoffmannForest': 'role_4',
#  'HoffmannSpiegel': 'role_0',
#  'Hol_Schroeder': 'role_1',
#  'HolgerEwald1': 'role_7',
#  'HolgerMannLE': 'role_4',
#  'HolgerScherer': 'role_4',
#  'Holger_Lucius': 'role_0',
#  'Holger_Michel': 'role_0',
#  'HollsteinM': 'role_0',
#  'HolzwarthUwe': 'role_7',
#  'Holzwur42869395': 'role_3',
#  'HomeHenrietta': 'role_6',
#  'HondaBerlin': 'role_6',
#  'Hooperman19': 'role_0',
#  'HornbachManfred': 'role_1',
#  'HorstKomm': 'role_0',
#  'Hosenmaus1': 'role_7',
#  'HotPlotz': 'role_6',
#  'HoubenReinhard': 'role_0',
#  'HuberJoachim': 'role_0',
#  'HubertAiwanger': 'role_0',
#  'HuebnerJohannes': 'role_0',
#  'Hufeisen4': 'role_4',
#  'HugoMuellerVogg': 'role_0',
#  'Hy1978M': 'role_3',
#  'HybridOrgan': 'role_3',
#  'ICONISTbyWELT': 'role_0',
#  'IDGroupEP': 'role_0',
#  'IMB91': 'role_0',
#  'IMeeresgeist': 'role_0',
#  'IT_Digital_AC': 'role_0',
#  'IWillIlluminate': 'role_7',
#  'I_Recker': 'role_6',
#  'IbrahimYetim': 'role_4',
#  'Ich2ES': 'role_2',
#  'IchMench': 'role_6',
#  'Ich_Michael_R': 'role_3',
#  'IchwillPflege': 'role_1',
#  'Iggi_rodentia': 'role_0',
#  'IllyricumSoul': 'role_4',
#  'IlselotteK': 'role_6',
#  'IlvesToomas': 'role_0',
#  'InaSchultz': 'role_0',
#  'Infinytii': 'role_1',
#  'IngaLutz': 'role_0',
#  'Ingo69160060': 'role_6',
#  'IngridWiegel': 'role_6',
#  'IngwerBaum': 'role_3',
#  'InkaGoRe': 'role_4',
#  'Inklusionsling': 'role_0',
#  'InneKomm': 'role_0',
#  'Inspect45409871': 'role_0',
#  'Instinktmaschi2': 'role_4',
#  'Interne21191899': 'role_6',
#  'IreneCologne': 'role_1',
#  'IreneMihalic': 'role_1',
#  'IrisSpranger': 'role_3',
#  'IrisW2608': 'role_0',
#  'Iro09908973': 'role_0',
#  'IsaCzokAlm': 'role_0',
#  'IsabelleVandre': 'role_0',
#  'Isi_von_Statten': 'role_5',
#  'IsmailErtug': 'role_4',
#  'IundeMaexchen': 'role_0',
#  'Iwan_Ivanowic': 'role_6',
#  'J0H': 'role_0',
#  'J3rryenteignet': 'role_3',
#  'JA_Deutschland': 'role_0',
#  'JArenhovel': 'role_0',
#  'JBrandenburgFDP': 'role_2',
#  'JCBaktiste': 'role_1',
#  'JCornio': 'role_0',
#  'JCrueger': 'role_0',
#  'JD19482': 'role_3',
#  'JHRibbat': 'role_6',
#  'JKolleck': 'role_0',
#  'JM_Luczak': 'role_4',
#  'JRehborn': 'role_0',
#  'JScharfenort': 'role_0',
#  'JSt04092834': 'role_7',
#  'JTrittin': 'role_4',
#  'JURLP': 'role_0',
#  'J_B_oo7': 'role_0',
#  'J_Guggenbichler': 'role_1',
#  'J_Klein62': 'role_3',
#  'J_Liberalismus': 'role_0',
#  'J_Zachrau': 'role_3',
#  'JaSiebert': 'role_0',
#  'JackScho2': 'role_0',
#  'JakobSchlandt': 'role_0',
#  'JanAlbrecht': 'role_0',
#  'JanRedmannWk': 'role_4',
#  'JanaHusmann': 'role_0',
#  'JaneSchulzAfD': 'role_0',
#  'JaninaDuncan97': 'role_0',
#  'Janinapfau': 'role_4',
#  'JanineMerz': 'role_0',
#  'Janine_Wissler': 'role_7',
#  'JannikGotte': 'role_0',
#  'Jans_world_twit': 'role_0',
#  'JarufJilalij': 'role_1',
#  'JasperBauer': 'role_0',
#  'JayKay4077': 'role_6',
#  'JayKayCool': 'role_3',
#  'Jbg86139112': 'role_6',
#  'JeAhr711': 'role_3',
#  'JeanPascal_Hohm': 'role_0',
#  'JeanVanRijn': 'role_0',
#  'JeannaieLaLuna': 'role_6',
#  'JeanyLeinweber': 'role_4',
#  'JemellaJessica': 'role_3',
#  'Jeniffe83264866': 'role_7',
#  'JensFrank6': 'role_6',
#  'JensHS8': 'role_0',
#  'JensHerforth': 'role_0',
#  'JensMunster': 'role_0',
#  'JensPet76057627': 'role_1',
#  'JensZSPD': 'role_4',
#  'JeremyCliffe': 'role_0',
#  'Jevx31': 'role_6',
#  'JilgAntje': 'role_4',
#  'JimBrowski969': 'role_6',
#  'JoSteiniger': 'role_4',
#  'JoWiegelmann': 'role_0',
#  'JoachimHummel': 'role_6',
#  'JoachimPaul_AfD': 'role_0',
#  'JoachimStamp': 'role_0',
#  'Joachim_Kuhs': 'role_0',
#  'JoanaCotar': 'role_0',
#  'Joanne13Harding': 'role_0',
#  'JoeHeinZ16': 'role_3',
#  'JoergGeerlings': 'role_4',
#  'JoergSchindler': 'role_0',
#  'JoergSin': 'role_6',
#  'JoergWammers': 'role_0',
#  'Joerg_Arndt': 'role_0',
#  'Joerg_Meuthen': 'role_0',
#  'JoernCarmaker': 'role_0',
#  'JoeyGerlach': 'role_0',
#  'Joffrey77855104': 'role_0',
#  'JohKraft': 'role_0',
#  'JohannEs2076': 'role_6',
#  'Johann_v_d_Bron': 'role_0',
#  'JohannesNormann': 'role_7',
#  'JohnJonnie1': 'role_0',
#  'JohnLiebau': 'role_0',
#  'JohniJorge': 'role_4',
#  'Jolpo3': 'role_0',
#  'JonahT_SPD': 'role_0',
#  'JonasUrbach': 'role_1',
#  'Jonas_7384': 'role_6',
#  'Jonathan_Happ': 'role_5',
#  'JonusKhaan': 'role_0',
#  'JooJoox3': 'role_6',
#  'JorgKipper': 'role_3',
#  'JosefinePaul': 'role_0',
#  'JoshHermannFDP': 'role_6',
#  'JoswigJulian': 'role_0',
#  'JoypadLadShop': 'role_0',
#  'Jrg20320811': 'role_6',
#  'JuLisNDS': 'role_0',
#  'JuTime': 'role_0',
#  'JuliaKloeckner': 'role_2',
#  'Julian86431717': 'role_6',
#  'Julian_Bruening': 'role_0',
#  'Juliane_Seifert': 'role_0',
#  'Julius70118572': 'role_3',
#  'JuliusBetschka': 'role_0',
#  'Jumpsteady': 'role_0',
#  'JungNaiv': 'role_0',
#  'Junge_Union': 'role_0',
#  'JunkMediaDE': 'role_0',
#  'JurgenHacker1': 'role_3',
#  'JurgenRohrbeck': 'role_6',
#  'Jus_Koenig': 'role_0',
#  'JusosCalw': 'role_0',
#  'Just_Johannes': 'role_7',
#  'JustcallmeLuci': 'role_4',
#  'JustusSchmitt': 'role_0',
#  'JuttaPaulusRLP': 'role_4',
#  'KATZOJ': 'role_2',
#  'KBabaraka': 'role_3',
#  'KCLeipzigerLand': 'role_0',
#  'KEbnerSteiner': 'role_7',
#  'KJPGehrden': 'role_0',
#  'KJagganazsd': 'role_3',
#  'KLeikert': 'role_5',
#  'KLompscher': 'role_0',
#  'KM_BW': 'role_0',
#  'KMerzenich': 'role_6',
#  'KPuschmann': 'role_1',
#  'KSTA': 'role_0',
#  'KTsilimekis': 'role_0',
#  'K_R_MUC': 'role_1',
#  'K_Rudolph_SPD': 'role_3',
#  'K_SA': 'role_4',
#  'KaOsSchweiz': 'role_0',
#  'KaPri11782464': 'role_2',
#  'Ka_Meier': 'role_0',
#  'Kace8105': 'role_3',
#  'KaczmarekOliver': 'role_0',
#  'Kaffee_u_Buch': 'role_0',
#  'KaiBunchOfNo': 'role_7',
#  'KaiGehring': 'role_4',
#  'KaiHarloff': 'role_3',
#  'KaiMeinecke': 'role_0',
#  'KaiSchulze_': 'role_0',
#  'Kaiser_SPD': 'role_4',
#  'Kajo2009': 'role_0',
#  'Kaler_Berlin': 'role_0',
#  'Kali1807': 'role_6',
#  'Kalle3D': 'role_3',
#  'Kalle83911267': 'role_3',
#  'KampferWahrheit': 'role_0',
#  'KarambaDiaby': 'role_0',
#  'KarenKoetje': 'role_0',
#  'KarinHollerthal': 'role_1',
#  'KarlDerKaefer0': 'role_6',
#  'KarlFreller': 'role_0',
#  'KarlGVock': 'role_6',
#  'Karl_Lauterbach': 'role_5',
#  'Karl_Raaben': 'role_6',
#  'Karl_Riede': 'role_3',
#  'KartesMdB': 'role_4',
#  'Kashman33536686': 'role_3',
#  'KathaKlarname': 'role_0',
#  'KathaSchulze': 'role_3',
#  'Kathagaros': 'role_0',
#  'KatharinaKoenig': 'role_7',
#  'KatharinaWittk3': 'role_3',
#  'KathrinBischoff': 'role_4',
#  'Kati_Engel': 'role_0',
#  'Katina_Schubert': 'role_0',
#  'Katinka1368': 'role_7',
#  'Katja84174609': 'role_7',
#  'KatjaMast': 'role_4',
#  'KatjaMitteldorf': 'role_7',
#  'KatjesHansen': 'role_0',
#  'Katrin73422154': 'role_0',
#  'KatrinD80003849': 'role_0',
#  'Katsanchebli': 'role_7',
#  'KawiKla': 'role_0',
#  'KayaKinkel': 'role_4',
#  'KaymanMurat': 'role_0',
#  'KazunguHass': 'role_0',
#  'KeeyulDendris': 'role_6',
#  'Keilerheute': 'role_6',
#  'Keksy19': 'role_5',
#  'Kellerpass': 'role_0',
#  'KerstinCelina': 'role_0',
#  'KerstinGriese': 'role_0',
#  'KerstinKopp7': 'role_7',
#  'KerstinLieder3': 'role_5',
#  'KerstinPress': 'role_5',
#  'Kerstin_Mueller': 'role_0',
#  'KflexK': 'role_7',
#  'Kh0815oderso': 'role_6',
#  'KhSchenk': 'role_3',
#  'KimSieber4': 'role_7',
#  'KinderdocNina': 'role_0',
#  'Kinderdoktorin': 'role_0',
#  'Kingdomcometous': 'role_0',
#  'KippelsNicole': 'role_3',
#  'KirstenGerhards': 'role_6',
#  'KirstenKappert': 'role_4',
#  'KirstenTackmann': 'role_7',
#  'Kitsuagi': 'role_0',
#  'Kla138': 'role_3',
#  'KlassikStiftung': 'role_0',
#  'KlausAdelt': 'role_4',
#  'KlausBeckmann6': 'role_6',
#  'KlausEuteneuer': 'role_0',
#  'KlausMl67471449': 'role_0',
#  'KlausObergfell': 'role_0',
#  'KlausWeckbach': 'role_0',
#  'Klawunke': 'role_0',
#  'KlimalisteRLP': 'role_0',
#  'KntktGrAHaftDD': 'role_0',
#  'KoehlerClaudia7': 'role_0',
#  'KoenigDickBauch': 'role_6',
#  'Koenigin_Chaos': 'role_0',
#  'KoeppelRoger': 'role_0',
#  'KoheletDP': 'role_6',
#  'KohlmeierSPD': 'role_0',
#  'KokospalmeBlog': 'role_7',
#  'Kolibri32522549': 'role_7',
#  'Komische_Oper': 'role_0',
#  'Konni': 'role_0',
#  'Konrad': 'role_2',
#  'KonstantinKuhle': 'role_1',
#  'KonstantinNotz': 'role_2',
#  'KontraAbtreiben': 'role_0',
#  'Koogle91417074': 'role_0',
#  'KostenloseE': 'role_6',
#  'KrahMax': 'role_0',
#  'Krakengarten': 'role_0',
#  'Krawallstein': 'role_1',
#  'Kreddy_Fruegger': 'role_3',
#  'Kreis_Lippe': 'role_0',
#  'KreuzAcht': 'role_0',
#  'Kronos272': 'role_5',
#  'Krullemuck': 'role_0',
#  'KuddlDaddldu': 'role_6',
#  'KuehniKev': 'role_1',
#  'Kuerbislecker': 'role_1',
#  'Kuhfluesterer': 'role_0',
#  'Kuniotchi': 'role_0',
#  'KurtTaylanz': 'role_0',
#  'Kyope121': 'role_6',
#  'L1berta5': 'role_6',
#  'LINKEBergedorf': 'role_0',
#  'LINKEPELLI': 'role_4',
#  'LJohrendt': 'role_7',
#  'LSB_SN': 'role_0',
#  'L_Petersdotter': 'role_2',
#  'Lambsdorff': 'role_0',
#  'LandesMemeAnsta': 'role_7',
#  'Landtag_NRW': 'role_0',
#  'LangLINKE': 'role_0',
#  'LangeJulian': 'role_0',
#  'Lanyihunter1': 'role_0',
#  'LarissaBlum1991': 'role_1',
#  'LarsFrohmueller': 'role_4',
#  'LarsLeopold': 'role_4',
#  'Laschet': 'role_0',
#  'Lasher67227061': 'role_7',
#  'LauHofmann': 'role_0',
#  'Laura89602297': 'role_0',
#  'LeahCim41504544': 'role_3',
#  'Lebensliebend': 'role_4',
#  'LeeGesundemitte': 'role_4',
#  'LeeorEnglander': 'role_5',
#  'LeibundgutEdith': 'role_7',
#  'LeineUnd': 'role_0',
#  'Lena55856547': 'role_7',
#  'LenaTernes': 'role_6',
#  'Lena_Star98': 'role_7',
#  'LeniBreymaier': 'role_4',
#  'LenzRamona': 'role_0',
#  'LeoFuchs13': 'role_3',
#  'Leo___Sturm': 'role_3',
#  'Leonie_3639': 'role_3',
#  'LiMiBRB': 'role_1',
#  'Lib_R_Tarian': 'role_6',
#  'LiberalMut': 'role_0',
#  'LibertyLucas26': 'role_0',
#  'Libra08101': 'role_0',
#  'LichFrau': 'role_5',
#  'LieberGott5': 'role_5',
#  'LieblingXhain': 'role_2',
#  'Lighthouse5910': 'role_3',
#  'Liisamariie1997': 'role_0',
#  'Lilablau23': 'role_7',
#  'Lillithinpeace': 'role_6',
#  'LillyBlaudszun': 'role_0',
#  'LindaTeuteberg': 'role_2',
#  'LineWulf': 'role_1',
#  'Linke_Thl': 'role_0',
#  'Linke_Watch': 'role_7',
#  'Linksfraktion': 'role_7',
#  'LinksfraktionB': 'role_0',
#  'Lipperlaender1': 'role_5',
#  'Lisa96437408': 'role_6',
#  'LisaMariaOtte': 'role_2',
#  'Lisanet16': 'role_6',
#  'Littlecrow110': 'role_6',
#  'LoeserKilian': 'role_7',
#  'Lokoschat': 'role_0',
#  'LongCovidKids': 'role_0',
#  'LordCario34': 'role_4',
#  'LordComander762': 'role_3',
#  'Lorddarling1': 'role_3',
#  'LorenzSpecht': 'role_0',
#  'LosLeventos': 'role_7',
#  'LotfiMhamdi4': 'role_0',
#  'Lothar_Binding': 'role_0',
#  'LovePeaceNPop': 'role_3',
#  'LoveRetroBTW': 'role_0',
#  'Lowbrush1': 'role_3',
#  'LudwigHartmann': 'role_0',
#  'LuigiPantisano': 'role_0',
#  'Luisamneubauer': 'role_0',
#  'LuiseNeuhaus': 'role_4',
#  'LukasH77694965': 'role_0',
#  'LukasKilian': 'role_2',
#  'LukasMobus': 'role_3',
#  'Lukas_Miebach': 'role_0',
#  'Lukreta_': 'role_0',
#  'LutzLiebscher': 'role_4',
#  'LutzvanderHorst': 'role_0',
#  'M10977012': 'role_7',
#  'M12010111': 'role_1',
#  'M1am1H': 'role_3',
#  'M47514535': 'role_3',
#  'MARC_2U': 'role_6',
#  'MATmaschke': 'role_3',
#  'MBK_Saar': 'role_0',
#  'MBiadaczMdB': 'role_3',
#  'MDR_SAN': 'role_0',
#  'MDR_SN': 'role_0',
#  'MDRpresse': 'role_0',
#  'MDertos': 'role_3',
#  'MEDIEN360G': 'role_0',
#  'MEtzold': 'role_0',
#  'MFeldenkirchen': 'role_0',
#  'MFeldmayer': 'role_4',
#  'MGGA2021h': 'role_0',
#  'MGindorf': 'role_0',
#  'MGoormann': 'role_6',
#  'MGrosseBroemer': 'role_3',
#  'MH55198499': 'role_6',
#  'MICHAaeIAnders': 'role_6',
#  'MIT_bund': 'role_0',
#  'MJatbottle': 'role_4',
#  'MK27560487': 'role_7',
#  'MK_aus_H': 'role_0',
#  'MKies75': 'role_7',
#  'MKreutzfeldt': 'role_0',
#  'MM23428186': 'role_5',
#  'MM_Fakt': 'role_6',
#  'MM_Mbuna': 'role_7',
#  'MMittermeier': 'role_0',
#  'MMundelein': 'role_0',
#  'MOTSI_MABUSE': 'role_0',
#  'MR1200rt': 'role_0',
#  'MRanninger': 'role_3',
#  'MS1989muc1': 'role_6',
#  'MSGIV_BB': 'role_0',
#  'MSI_BW': 'role_0',
#  'MSchroeren': 'role_0',
#  'MTaege': 'role_0',
#  'MVBewohner': 'role_0',
#  'MV_AM': 'role_0',
#  'MWBirkwald': 'role_0',
#  'MYkrzysztof': 'role_7',
#  'M_Baroudeur': 'role_0',
#  'M_Chr1stian': 'role_0',
#  'M_HarderKuehnel': 'role_0',
#  'M_Hundhausen': 'role_0',
#  'M_Ostermann': 'role_0',
#  'M_Reichardt_AfD': 'role_0',
#  'M_Wiegelmann': 'role_3',
#  'M_Ziesmann': 'role_0',
#  'MaWitt7': 'role_0',
#  'MaWollscheid': 'role_0',
#  'MacalaniaMagic': 'role_7',
#  'Machdanichtmit': 'role_6',
#  'MadsackM': 'role_0',
#  'Madsee6553211': 'role_6',
#  'MagdaleneStosik': 'role_1',
#  'Magdarine': 'role_0',
#  'MagicSpaceBurns': 'role_7',
#  'MagnusHeise': 'role_0',
#  'MaierJrg1': 'role_4',
#  'MaikBeermann': 'role_7',
#  'Malevil4Free': 'role_3',
#  'MaliFan1804': 'role_0',
#  'Malliki11': 'role_0',
#  'Malte45293403': 'role_7',
#  'MalteDetje': 'role_0',
#  'MalteKaufmann': 'role_0',
#  'MalteLehming': 'role_0',
#  'Mama_arbeitet': 'role_0',
#  'ManfredSchirmer': 'role_3',
#  'ManjaSchuele': 'role_0',
#  'ManuelaRottman': 'role_0',
#  'ManuelaSchwesig': 'role_0',
#  'MarcBorchers': 'role_0',
#  'MarcFelixSerrao': 'role_3',
#  'MarcMeiritz': 'role_0',
#  'MarcPat14643105': 'role_6',
#  'MarcReeze': 'role_6',
#  'MarcSpeicher': 'role_3',
#  'Marc_303BK': 'role_1',
#  'Marc_Maurice_K': 'role_5',
#  'Marc_Urbatsch': 'role_2',
#  'Marc_Win': 'role_6',
#  'Marcell08425664': 'role_0',
#  'Marcelli1314': 'role_3',
#  'MarchandYannik': 'role_1',
#  'Marco7264694275': 'role_6',
#  'MarcoBuschmann': 'role_0',
#  'MarcoMohrmann': 'role_0',
#  'MarcoWeberEifel': 'role_0',
#  'Marcruland': 'role_4',
#  'Marcus05911286': 'role_7',
#  'MarcusCyron': 'role_1',
#  'MarcusFaber': 'role_0',
#  'MarcusPretzell': 'role_7',
#  'MarenJasper': 'role_1',
#  'MariaKlSchmeink': 'role_3',
#  'MariaNoichl': 'role_7',
#  'MarianBracht': 'role_4',
#  'Marie_Kr2': 'role_0',
#  'MarieluiseBeck': 'role_0',
#  'MarioCzaja': 'role_4',
#  'MarioQuade': 'role_0',
#  'MarioS94470956': 'role_7',
#  'MarionLill': 'role_5',
#  'MarionaMarione': 'role_2',
#  'Marioncrowefan': 'role_0',
#  'Marita658078351': 'role_3',
#  'Marius_Raabe': 'role_0',
#  'MarkusBlume': 'role_4',
#  'MarkusLatt': 'role_3',
#  'MarkusM1978': 'role_6',
#  'MarkusNielbock': 'role_0',
#  'MarkusS46413444': 'role_3',
#  'MarkusSonderman': 'role_6',
#  'MarkusTalla26': 'role_0',
#  'Markus_Krall': 'role_0',
#  'Markus_Soeder': 'role_0',
#  'Markus_Wojahn': 'role_0',
#  'MarlenBlock': 'role_4',
#  'Marmeleni': 'role_3',
#  'MartGuenzel': 'role_5',
#  'Martin33113': 'role_3',
#  'Martin46er1': 'role_6',
#  'MartinG52841672': 'role_6',
#  'MartinGrauzone': 'role_5',
#  'MartinHaeusling': 'role_0',
#  'MartinHaller': 'role_7',
#  'MartinOktober': 'role_6',
#  'MartinRosemann': 'role_2',
#  'MartinS01186541': 'role_5',
#  'MartinSchaefer1': 'role_7',
#  'MartinSchulz': 'role_0',
#  'MartinWaltherDD': 'role_1',
#  'Martin_Schwizer': 'role_0',
#  'MartinaRenner': 'role_0',
#  'MaryLienkamp': 'role_6',
#  'MaryMieze': 'role_5',
#  'MaryMueller1904': 'role_3',
#  'Mary_Blumenthal': 'role_3',
#  'Mary_Khan94': 'role_0',
#  'MathiasPriebe': 'role_0',
#  'MatrixDisconne1': 'role_3',
#  'MatthaeusMonz': 'role_0',
#  'Matthau63': 'role_6',
#  'MattheusBerg': 'role_0',
#  'MatthiasGastel': 'role_0',
#  'MatthiasGrimm14': 'role_4',
#  'MatthiasHauer': 'role_7',
#  'MatthiasHoehn': 'role_0',
#  'MauriceHoefgen': 'role_0',
#  'MauriceShahd': 'role_6',
#  'Maurice_Conrad': 'role_0',
#  'Max42878292': 'role_0',
#  'Max60543512': 'role_3',
#  'MaxFellner5': 'role_3',
#  'MaxLinke_': 'role_0',
#  'Maximilian_Popp': 'role_0',
#  'Maxpower692': 'role_7',
#  'MayaQuany': 'role_1',
#  'Mayergibtsschon': 'role_0',
#  'McAviti': 'role_5',
#  'McRich_n_hard': 'role_0',
#  'MckStf': 'role_0',
#  'MdBMonstadt': 'role_0',
#  'MdB_Schmidtke': 'role_7',
#  'MdB_Schreiber': 'role_7',
#  'MechthildHeil': 'role_1',
#  'MehlhornMartin': 'role_7',
#  'Mehriel': 'role_0',
#  'MeinLebenalsBot': 'role_0',
#  'MeinePolitik': 'role_3',
#  'Meinungsbaum': 'role_0',
#  'MelAmann': 'role_0',
#  'MelBurn02025218': 'role_6',
#  'MelanieBergma18': 'role_3',
#  'Melanka61743917': 'role_1',
#  'Mellcolm': 'role_1',
#  'MelodyBayerin': 'role_0',
#  'Menkhaus_AfD': 'role_0',
#  'Mera63290121': 'role_0',
#  'Meriptah': 'role_7',
#  'MerkuristM': 'role_0',
#  'MeronMendel': 'role_0',
#  'MetinHakverdi': 'role_3',
#  'Meyer_FDP': 'role_1',
#  'Meyermit_ey': 'role_0',
#  'MiGrPhotography': 'role_6',
#  'MiKellner': 'role_3',
#  'MiRo_SPD': 'role_0',
#  'MiWae21': 'role_4',
#  'Micha68LG': 'role_5',
#  'Michael22221813': 'role_6',
#  'MichaelBaleanu': 'role_5',
#  'MichaelBroecker': 'role_1',
#  'MichaelGriesbe3': 'role_3',
#  'MichaelReckordt': 'role_0',
#  'MichaelRueter': 'role_0',
#  'MichaelZechner3': 'role_0',
#  'Michael_2305': 'role_7',
#  'Michael_Jahn_GB': 'role_0',
#  'Michael_Wue': 'role_5',
#  'Michael___K': 'role_3',
#  'MichaelaWiegel': 'role_0',
#  'MichaelaWifi': 'role_3',
#  'Micky27182': 'role_0',
#  'MickyBeisenherz': 'role_4',
#  'MieruchMario': 'role_7',
#  'Miesmuschel101': 'role_6',
#  'Miguel27610586': 'role_3',
#  'Mihaitz92297086': 'role_6',
#  'MikeDeeeeeee': 'role_2',
#  'MikeMohring': 'role_3',
#  'Mike__happy': 'role_0',
#  'Minimalstaat': 'role_1',
#  'Minyas49866842': 'role_7',
#  'Mio84269003': 'role_7',
#  'Miquwarchar': 'role_4',
#  'MiracleMan82': 'role_0',
#  'MiriHaussecker': 'role_0',
#  'MirkoCramer': 'role_0',
#  'Miro875': 'role_0',
#  'MissBJArmstrong': 'role_0',
#  'Missy51832227': 'role_3',
#  'MisterA172': 'role_3',
#  'MitMirNicht1': 'role_0',
#  'MitRolf': 'role_0',
#  'MiteinanderCGN': 'role_0',
#  'MitriSirin': 'role_0',
#  'Mjoelnir14': 'role_0',
#  'MoCha69715998': 'role_1',
#  'MoSchaefer66': 'role_6',
#  'MobiDic22912923': 'role_0',
#  'Mobile_Beratung': 'role_0',
#  'MobyNikk': 'role_0',
#  'MoebusAnne': 'role_0',
#  'Moehroe': 'role_0',
#  'MoellerAfD': 'role_0',
#  'Mohnblu68093308': 'role_3',
#  'MohrNora1': 'role_6',
#  'Mohrenpost': 'role_0',
#  'Mok1967SG': 'role_0',
#  'Mokkalas': 'role_6',
#  'Mollzi2011': 'role_3',
#  'MonaHosseini_': 'role_4',
#  'MoneLis35456408': 'role_5',
#  'MonikaHerrmann1': 'role_0',
#  'MonsieurWelsch': 'role_0',
#  'MoraDiletta': 'role_6',
#  'MoritzKenk': 'role_0',
#  'MoschSabine': 'role_0',
#  'MrBrianRix': 'role_6',
#  'MrFitCoin1': 'role_6',
#  'MrJayTrasher': 'role_6',
#  'MrNeolix': 'role_0',
#  'Mr_Talisker': 'role_1',
#  'MsBonnyParker': 'role_0',
#  'MucksBueker': 'role_4',
#  'Mueller1G': 'role_7',
#  'MuellerChemnitz': 'role_4',
#  'Mueller_M12': 'role_1',
#  'Muenstermann999': 'role_0',
#  'Muetterforum': 'role_0',
#  'Muhterem_Aras': 'role_0',
#  'Mukkele': 'role_6',
#  'Mumfred67': 'role_4',
#  'MunzerStephan': 'role_6',
#  'MusicIndolent': 'role_0',
#  'Musketler': 'role_0',
#  'MyHamster_1': 'role_0',
#  'NB_PinkiPink': 'role_3',
#  'ND3v2': 'role_4',
#  'NDMedienmacher': 'role_0',
#  'NDRinfo': 'role_0',
#  'NDRpresse': 'role_0',
#  'NEOPATRIA1': 'role_6',
#  'NEUMEdIER': 'role_0',
#  'NGJokesh': 'role_2',
#  'NHC_Atlantic': 'role_0',
#  'NHoffmannAfDTh': 'role_0',
#  'NJaehring': 'role_4',
#  'NOAASatellites': 'role_0',
#  'NSU_Tribunal': 'role_0',
#  'NTVNEWS': 'role_0',
#  'NTVsSteveWhite': 'role_0',
#  'NZZ': 'role_0',
#  'NZZde': 'role_0',
#  'NadineJulitz': 'role_0',
#  'NadineRank': 'role_0',
#  'NadineSchoen': 'role_4',
#  'NaechsteRunde': 'role_0',
#  'NaikeLeNormand': 'role_3',
#  'Naindri2012': 'role_0',
#  'NalanSipar': 'role_0',
#  'Nali_Ostmann': 'role_6',
#  'NancyFaeser': 'role_4',
#  'NatalieAmiri': 'role_0',
#  'NatalieGrams': 'role_0',
#  'NataschaKohnen': 'role_2',
#  'NaturBergmensch': 'role_7',
#  'Natural36208783': 'role_6',
#  'Naturfreund_81': 'role_7',
#  'NeverEv52073953': 'role_0',
#  'NewFlashlight': 'role_0',
#  'News4teachers': 'role_0',
#  'Newt24021897': 'role_6',
#  'Nico': 'role_0',
#  'Nico818626643': 'role_6',
#  'NicolasSustr': 'role_0',
#  'Nicolaus_Fest': 'role_0',
#  'Nicole21249915': 'role_7',
#  'NicoleWestig': 'role_0',
#  'NiemaMovassat': 'role_7',
#  'Niggo97507866': 'role_6',
#  'Nightmare_Keks': 'role_0',
#  'NiklasKossow': 'role_0',
#  'NiklasSchenker': 'role_0',
#  'NikolausBlome': 'role_0',
#  'NineBerry': 'role_0',
#  'Niniho1': 'role_3',
#  'Nintendork9': 'role_0',
#  'Nixdorf4': 'role_2',
#  'No934': 'role_0',
#  'NoafD': 'role_0',
#  'NobisHodie': 'role_0',
#  'NoelKramerSPD': 'role_0',
#  'Nomercywitsissy': 'role_6',
#  'Noodles2506': 'role_0',
#  'NoraBless60': 'role_7',
#  'NorbertBolz': 'role_0',
#  'Norbert_MdB': 'role_0',
#  'NordMdb': 'role_4',
#  'Nordfriesland': 'role_6',
#  'Normen801': 'role_6',
#  'Nornenland': 'role_0',
#  'Norther95763510': 'role_0',
#  'NotkerBerlin': 'role_4',
#  'Novavax': 'role_0',
#  'NowaboFM': 'role_4',
#  'NuffSaid1922': 'role_7',
#  'NurderK': 'role_1',
#  'NutzSibi': 'role_0',
#  'Nutzername48916': 'role_0',
#  'Nutzernameneu': 'role_2',
#  'ODoeschi': 'role_0',
#  'OKehrl': 'role_1',
#  'OStraubing': 'role_7',
#  'OUltraz': 'role_0',
#  'O_Sundermeyer': 'role_0',
#  'Obg1887': 'role_7',
#  'OezlemADemirel': 'role_7',
#  'OlGr17': 'role_7',
#  'Olaf88352109': 'role_6',
#  'OlafGersemann': 'role_0',
#  'OlafScholz': 'role_0',
#  'OlafStorbeck': 'role_0',
#  'OlafWegner4': 'role_6',
#  'Ole_Funke': 'role_0',
#  'Oli2111': 'role_6',
#  'OliWolf88': 'role_6',
#  'Olire4': 'role_3',
#  'OlisCartoons': 'role_0',
#  'Olivchen89': 'role_6',
#  'OliverJuetting': 'role_0',
#  'Oliver_Krischer': 'role_3',
#  'Olli08641776': 'role_6',
#  'OlliLuksic': 'role_4',
#  'Oltmann26': 'role_0',
#  'OnkelMattiVau': 'role_6',
#  'OomenBerlin': 'role_0',
#  'OpheliaNick': 'role_3',
#  'Oracle___': 'role_7',
#  'Oramo111': 'role_5',
#  'Orgelkurt1': 'role_0',
#  'Osgyan': 'role_0',
#  'OsignalC': 'role_0',
#  'OsterhalVon': 'role_0',
#  'OstiOstfriesin': 'role_0',
#  'Ostseemom': 'role_0',
#  'OttoRuger': 'role_3',
#  'Otto_Fricke': 'role_2',
#  'OurWorldInData': 'role_0',
#  'Outlander1901': 'role_6',
#  'OverTyranny': 'role_5',
#  'PARTEI': 'role_0',
#  'PARTEIESSEN': 'role_4',
#  'PBanause': 'role_0',
#  'PCOrthy': 'role_6',
# ...
#  'nicolediekmann': 'role_0',
#  'nifberlin': 'role_0',
#  'nikitheblogger': 'role_0',
#  'nila95193790': 'role_0',
#  'nili1966': 'role_0',
#  'ninastahr': 'role_0',
#  'ninawarken': 'role_4',
#  'nminkmar': 'role_0',
#  'noahbarkin': 'role_3',
#  'nochnteichungh1': 'role_0',
#  'nolifedie': 'role_5',
#  'nomad_4ever': 'role_0',
#  'nomnomcookieez': 'role_0',
#  'noname_nrw': 'role_5',
#  'nopasserat': 'role_6',
#  'norapfue': 'role_0',
#  'norazabel': 'role_3',
#  'norberthense': 'role_0',
#  'nordkirche_de': 'role_4',
#  'nordlichtpercht': 'role_0',
#  'norwichruesse': 'role_4',
#  'notsureif_fry': 'role_1',
#  'novosang': 'role_1',
#  'novussubsole': 'role_1',
#  'nrwspd': 'role_0',
#  'ntv': 'role_0',
#  'ntv_EIL': 'role_0',
#  'ntvde': 'role_0',
#  'ntvde_Politik': 'role_4',
#  'nulldenker': 'role_0',
#  'number9_1982': 'role_3',
#  'nur_zusammen': 'role_1',
#  'nurdiespd': 'role_0',
#  'nurich08154711': 'role_7',
#  'nurnochmuede': 'role_6',
#  'nutellaberliner': 'role_0',
#  'o_jthe': 'role_3',
#  'oezoguz': 'role_4',
#  'offialkaren': 'role_7',
#  'oida_grantler': 'role_0',
#  'olafinderbeek': 'role_0',
#  'olafrannflfan': 'role_6',
#  'olafstampf': 'role_0',
#  'oleplambeck': 'role_4',
#  'oli_mller': 'role_0',
#  'oliver_junk': 'role_0',
#  'oliverstoer': 'role_6',
#  'one_ard': 'role_0',
#  'openculture': 'role_0',
#  'opiniorado': 'role_1',
#  'originalbrecht': 'role_0',
#  'ortskraefte': 'role_0',
#  'osanten': 'role_0',
#  'osservatore2004': 'role_3',
#  'otbhh': 'role_7',
#  'otto_direkt': 'role_0',
#  'owl_hm': 'role_0',
#  'p_a_t_t_y1': 'role_7',
#  'p_dresel': 'role_6',
#  'p_winninger': 'role_3',
#  'pablodiabolo': 'role_0',
#  'palamux': 'role_4',
#  'panzerschoko': 'role_5',
#  'papapreuss': 'role_0',
#  'pascal_lili': 'role_7',
#  'patriot_singles': 'role_3',
#  'paul_maximum': 'role_3',
#  'paul_schorsch': 'role_0',
#  'pdacu': 'role_0',
#  'per_velo': 'role_0',
#  'pestundcola': 'role_3',
#  'peteje66': 'role_3',
#  'petelkau': 'role_1',
#  'peter_simone': 'role_2',
#  'peter_srt8': 'role_7',
#  'peteregger20': 'role_6',
#  'petertauber': 'role_2',
#  'peterwinkelhub1': 'role_2',
#  'petra_naroska': 'role_4',
#  'petrimv': 'role_4',
#  'petrospaikos': 'role_7',
#  'pfarrer_kraus': 'role_0',
#  'ph_ato': 'role_0',
#  'ph_reporterpool': 'role_0',
#  'phasenkind': 'role_4',
#  'phasenweisheit': 'role_0',
#  'philipp_5110': 'role_4',
#  'philipp_fuer_DU': 'role_3',
#  'philipplenz6': 'role_0',
#  'philipsrck': 'role_0',
#  'philsandmann': 'role_0',
#  'physicsjan': 'role_0',
#  'pianoledge': 'role_0',
#  'pickert_ralf': 'role_6',
#  'pilgerpetrus': 'role_0',
#  'pinguinpetzi': 'role_0',
#  'pingupope': 'role_0',
#  'pippilia': 'role_3',
#  'pirate_baltic': 'role_0',
#  'pitgottschalk': 'role_3',
#  'pkerchner': 'role_0',
#  'platen_sascha': 'role_3',
#  'platz13': 'role_4',
#  'pmasner': 'role_0',
#  'poiterM': 'role_7',
#  'polenz_r': 'role_2',
#  'polizeiberlin': 'role_0',
#  'popupanna': 'role_0',
#  'presroi': 'role_0',
#  'pressepfarrerin': 'role_0',
#  'prof_freedom': 'role_0',
#  'profilonline': 'role_0',
#  'protest_lej': 'role_0',
#  'provoziert': 'role_6',
#  'psychomaennchen': 'role_3',
#  'psychomami1': 'role_0',
#  'punktpreradovic': 'role_3',
#  'purelyocean': 'role_3',
#  'pz20707884': 'role_5',
#  'qadRick': 'role_3',
#  'qpress42': 'role_0',
#  'quarkswdr': 'role_0',
#  'querfeminist': 'role_3',
#  'quirulant': 'role_3',
#  'radres75961560': 'role_0',
#  'radsportmagazin': 'role_0',
#  'ragamuffine21': 'role_6',
#  'raiksaw': 'role_0',
#  'rainersax': 'role_1',
#  'ralpe': 'role_0',
#  'ralphruthe': 'role_0',
#  'rammerrudolf': 'role_0',
#  'rampfer': 'role_6',
#  'raptor2_0': 'role_6',
#  'rasim2ran': 'role_3',
#  'rasmus_stuff': 'role_1',
#  'rassistenjaeger': 'role_3',
#  'raymond_walk': 'role_4',
#  'rbb24': 'role_0',
#  'rbbabendschau': 'role_0',
#  'rbrinkhaus': 'role_0',
#  'readonl95166975': 'role_3',
#  'realHelmchen': 'role_7',
#  'realTomBohn': 'role_0',
#  'real_Guido_T': 'role_0',
#  'real_baumi': 'role_0',
#  'rebell_kai': 'role_0',
#  'rebixisdad': 'role_6',
#  'reboehi': 'role_3',
#  'regina_kittler': 'role_4',
#  'reinholdmdb': 'role_1',
#  'reiseschreiber': 'role_5',
#  'reitschuster': 'role_0',
#  'rekurrierend': 'role_0',
#  'renebehrend': 'role_3',
#  'rennersen': 'role_0',
#  'renzsch': 'role_7',
#  'report24news': 'role_0',
#  'retinafunk': 'role_5',
#  'retrostyle3000': 'role_4',
#  'rezomusik': 'role_0',
#  'rhoenschnegge': 'role_0',
#  'ria_schroeder': 'role_0',
#  'ricardo_lerch': 'role_0',
#  'richfrisch': 'role_0',
#  'ricogebhardt': 'role_7',
#  'rike_tweet': 'role_4',
#  'rischwasu': 'role_4',
#  'risklayer': 'role_0',
#  'rki_de': 'role_0',
#  'rldml': 'role_7',
#  'rlpNews': 'role_0',
#  'robert_fietzke': 'role_0',
#  'robinalexander_': 'role_0',
#  'robinhaseler': 'role_4',
#  'rockToamna': 'role_7',
#  'rockamveritas': 'role_6',
#  'rockthelifemore': 'role_0',
#  'rohlie1969': 'role_3',
#  'ronnyrossin': 'role_7',
#  'ronzheimer': 'role_0',
#  'ropietsch': 'role_0',
#  'rosaVered': 'role_2',
#  'rosadomm_': 'role_4',
#  'rosarot_lang': 'role_0',
#  'rosenbusch_': 'role_0',
#  'rosenrot_m': 'role_0',
#  'roteLocke73': 'role_0',
#  'rtl': 'role_0',
#  'rtlgroup': 'role_0',
#  'rudi_anschober': 'role_0',
#  'rudiraffke': 'role_3',
#  'rue_chri': 'role_0',
#  'ruhrpottbaresi': 'role_3',
#  'rune187': 'role_6',
#  'ryaN_4k': 'role_3',
#  'ryut054KuR4': 'role_6',
#  's_k_walter': 'role_0',
#  'sabine18052012': 'role_0',
#  'sabine__w': 'role_6',
#  'sabine_mueller1': 'role_3',
#  'sabinedoering': 'role_0',
#  'sabineponath': 'role_0',
#  'saggfresse': 'role_7',
#  'sakobjurmann': 'role_0',
#  'salomon_alex': 'role_7',
#  'salsim5774': 'role_0',
#  'samu_laade': 'role_0',
#  'sandra2519691': 'role_0',
#  'sandra_weeser': 'role_0',
#  'sanindigital': 'role_3',
#  'santosherrmann': 'role_2',
#  'sara__weber': 'role_0',
#  'sarahbosetti': 'role_0',
#  'sarfeld': 'role_3',
#  'saschalobo': 'role_0',
#  'sasha_grrr': 'role_0',
#  'satire19': 'role_0',
#  'sbamueller': 'role_1',
#  'scarface_121012': 'role_7',
#  'schaefer_berlin': 'role_7',
#  'schaefer_j': 'role_0',
#  'schaefer_vgtlnd': 'role_3',
#  'schaeffer_nrw': 'role_4',
#  'schahinag': 'role_0',
#  'schatzbln': 'role_4',
#  'schaufeltrage': 'role_3',
#  'schieritz': 'role_0',
#  'schildbuerger73': 'role_6',
#  'schildetto': 'role_6',
#  'schirdewan': 'role_0',
#  'schlubilein': 'role_0',
#  'schmiddi1077': 'role_3',
#  'schneider_chris': 'role_5',
#  'schneidercar': 'role_3',
#  'schneiderdeluxe': 'role_3',
#  'schnobbelchen': 'role_6',
#  'schokomint': 'role_0',
#  'scholz': 'role_0',
#  'scholz4kanzler': 'role_0',
#  'scholz_dieter': 'role_0',
#  'schondudel': 'role_5',
#  'schonkloot': 'role_3',
#  'schorn_stephan': 'role_0',
#  'schreibtatze': 'role_0',
#  'schroeder_k': 'role_4',
#  'schtzle': 'role_7',
#  'schuhmacher76': 'role_6',
#  'schule_anders': 'role_0',
#  'schullegr': 'role_7',
#  'schulzeeuropa': 'role_3',
#  'schwarzblond': 'role_0',
#  'schwarzitlerei': 'role_6',
#  'schweizok2': 'role_0',
#  'schwerin19055': 'role_1',
#  'scibus': 'role_0',
#  'sebast_hartmann': 'role_4',
#  'sebastian_liest': 'role_6',
#  'sebastiank': 'role_4',
#  'sebastiankurz': 'role_0',
#  'seber1990': 'role_0',
#  'sebster2014': 'role_3',
#  'sebulino': 'role_0',
#  'selberdenker123': 'role_0',
#  'selcuksalih': 'role_4',
#  'senderas': 'role_7',
#  'senneka': 'role_1',
#  'sententia_Liber': 'role_5',
#  'sevenjelo': 'role_6',
#  'sgdozer': 'role_3',
#  'sgt_flower': 'role_0',
#  'shengfui': 'role_0',
#  'shiny_schiggy': 'role_0',
#  'shooting4alleu': 'role_1',
#  'sieberttommess': 'role_1',
#  'siggi2106': 'role_3',
#  'silv_den_': 'role_0',
#  'silver_bakk': 'role_6',
#  'simbosan': 'role_0',
#  'simonefoerter66': 'role_0',
#  'simonkeim': 'role_7',
#  'sinnertheo1': 'role_0',
#  'sinnesbichler': 'role_0',
#  'sir_sean_22': 'role_3',
#  'sis_teract': 'role_0',
#  'sixtus': 'role_0',
#  'skuggee': 'role_6',
#  'sl_luise': 'role_6',
#  'slzulcht': 'role_1',
#  'smatthes': 'role_0',
#  'smi_ni': 'role_7',
#  'snanews_de': 'role_0',
#  'sneakerskin1': 'role_3',
#  'socksocky2': 'role_0',
#  'soerenbartol': 'role_0',
#  'sofiamkaiser': 'role_4',
#  'sollerica33': 'role_0',
#  'sonichtbestellt': 'role_0',
#  'sophia73448182': 'role_6',
#  'sorrymefrench': 'role_3',
#  'sozialmann': 'role_6',
#  'spasevski_filip': 'role_6',
#  'spasssbremse': 'role_5',
#  'spd': 'role_0',
#  'spd_fraktion_nw': 'role_0',
#  'spdbawue': 'role_0',
#  'spdberlin': 'role_1',
#  'spdbt': 'role_0',
#  'spdde': 'role_2',
#  'spde': 'role_0',
#  'spdfraktionbln': 'role_0',
#  'spdhh': 'role_0',
#  'spdmuenster': 'role_0',
#  'spdrlp': 'role_0',
#  'spdwandsbek': 'role_0',
#  'spellerberg_m': 'role_0',
#  'spiegelonline': 'role_0',
#  'spindoktor_hc': 'role_5',
#  'spoekes111': 'role_0',
#  'sportstudio': 'role_0',
#  'sschnee3': 'role_0',
#  'sschyvonne': 'role_2',
#  'st_foerster': 'role_2',
#  'stabmixerr': 'role_6',
#  'stadtpoetin': 'role_0',
#  'stadtweimar': 'role_0',
#  'stark3881': 'role_0',
#  'starkwatzinger': 'role_1',
#  'stefan1531': 'role_0',
#  'stefan_vollmer': 'role_0',
#  'stefanie_fuchs': 'role_0',
#  'stefanolix': 'role_0',
#  'stefanziller': 'role_4',
#  'steffenundercov': 'role_3',
#  'stephanpalagan': 'role_0',
#  'stephanweil': 'role_0',
#  'stern280': 'role_6',
#  'sternde': 'role_0',
#  'sterni4ever': 'role_7',
#  'steve_ullmann': 'role_6',
#  'stevenkalus': 'role_0',
#  'sth269': 'role_7',
#  'stinkebutz': 'role_0',
#  'stohr_klaus': 'role_0',
#  'stonenews4': 'role_3',
#  'stonie_kiel': 'role_3',
#  'ststcccccc': 'role_3',
#  'stutenandy': 'role_6',
#  'sundaysforlife': 'role_0',
#  'suprion_verlag': 'role_6',
#  'susivili': 'role_5',
#  'sven_giegold': 'role_0',
#  'sven_kindler': 'role_2',
#  'sven_liebert': 'role_0',
#  'svenlehmann': 'role_0',
#  'svensonable1': 'role_0',
#  'svensonst': 'role_0',
#  'sveri80': 'role_1',
#  'svonhaxthausen': 'role_3',
#  'svs1946': 'role_0',
#  'swk_no1_eg': 'role_3',
#  'sybille_zoller': 'role_7',
#  'sylviageiger70': 'role_6',
#  'systemanalysen': 'role_5',
#  'syt_tkmk': 'role_3',
#  't0mez': 'role_4',
#  't0nky1': 'role_1',
#  't_e_e_k': 'role_3',
#  't_kurz': 'role_0',
#  't_woelfer': 'role_0',
#  'tagesschau': 'role_0',
#  'tagesthemen': 'role_0',
#  'tanit': 'role_0',
#  'tanzmaus1407': 'role_1',
#  'tapir_mit_maske': 'role_7',
#  'tazKlima': 'role_0',
#  'tazgezwitscher': 'role_0',
#  'tcomster': 'role_0',
#  'teambluelife': 'role_0',
#  'teamdeu': 'role_0',
#  'teamdpara': 'role_0',
#  'teleprism': 'role_0',
#  'teletabbe': 'role_6',
#  'teresabuecker': 'role_0',
#  'teskariel': 'role_0',
#  'testoiron': 'role_6',
#  'textlastig': 'role_0',
#  'textmagd': 'role_0',
#  'thPichler': 'role_0',
#  'th_sattelberger': 'role_7',
#  'the4thpip': 'role_5',
#  'theNeo42': 'role_4',
#  'theWellRedMage': 'role_0',
#  'the_real_urbsi': 'role_0',
#  'thekla_walker': 'role_0',
#  'themroc': 'role_0',
#  'theresahein_': 'role_3',
#  'thesismum': 'role_0',
#  'thewofb': 'role_5',
#  'thinkBTO': 'role_0',
#  'thomas2theleft': 'role_0',
#  'thomas_grieme': 'role_0',
#  'thomas_wiegold': 'role_0',
#  'thomasbogner9': 'role_7',
#  'thomasdudzak': 'role_0',
#  'thomaskowtsch': 'role_0',
#  'thommy_x': 'role_0',
#  'thon_atze': 'role_6',
#  'thoolb1': 'role_5',
#  'thorstenbenner': 'role_4',
#  'throwaway26389': 'role_5',
#  'thueringende': 'role_0',
#  'tibor': 'role_0',
#  'till_steffen': 'role_2',
#  'tillmoabit': 'role_3',
#  'timo_kon': 'role_0',
#  'timski04': 'role_0',
#  'tinastipps': 'role_0',
#  'tintenpro': 'role_7',
#  'tj_tweets': 'role_4',
#  'tjarkmelchert': 'role_4',
#  'tmie00988194': 'role_6',
#  'tmodc': 'role_3',
#  'tobiashans': 'role_0',
#  'tobiaslindner': 'role_3',
#  'tobihentze': 'role_0',
#  'tobirieder': 'role_0',
#  'tobybaier': 'role_0',
#  'toedchen1': 'role_6',
#  'tom21022': 'role_0',
#  'tom_nuttall': 'role_0',
#  'tom_s1706': 'role_0',
#  'tom_zeh': 'role_6',
#  'toma2401': 'role_6',
#  'tombuduk': 'role_1',
#  'tomsenjo': 'role_0',
#  'tonline': 'role_0',
#  'topac_fatos': 'role_4',
#  'torben_braga': 'role_0',
#  'torhamster04': 'role_0',
#  'torner_tv': 'role_1',
#  'torstenherbst': 'role_0',
#  'traumapparat': 'role_6',
#  'travelflo': 'role_0',
#  'trollopirat': 'role_0',
#  'tschlze': 'role_0',
#  'ttigger23': 'role_0',
#  'tu63867122': 'role_6',
#  'tumblraddictedm': 'role_5',
#  'turbogt3rs': 'role_6',
#  'tuxbox': 'role_3',
#  'tweets_con17': 'role_0',
#  'twiag1985': 'role_0',
#  'twisser': 'role_7',
#  'twittlik': 'role_0',
#  'twittschler': 'role_4',
#  'twogni': 'role_6',
#  'tx0h': 'role_0',
#  'tysonbarker': 'role_0',
#  'udowegener': 'role_6',
#  'uedio': 'role_0',
#  'ulfposh': 'role_0',
#  'ulixes24': 'role_3',
#  'ulle_schauws': 'role_2',
#  'ulligieseke': 'role_0',
#  'ulshoefer': 'role_0',
#  'umweltsau': 'role_6',
#  'unbeugsamenfilm': 'role_0',
#  'uninformedelde1': 'role_4',
#  'unitedfreedom3': 'role_3',
#  'uniteforfuture': 'role_7',
#  'unlogiker': 'role_3',
#  'unzensuriert': 'role_0',
#  'ursusistusus': 'role_4',
#  'urwaldpapagei11': 'role_3',
#  'useidler2': 'role_4',
#  'utabpunkt': 'role_0',
#  'utopia235': 'role_0',
#  'uwe30451143': 'role_0',
#  'uwe_kamann': 'role_0',
#  'v3rbalsalat': 'role_6',
#  'v_olberg': 'role_0',
#  'valentinschulz_': 'role_0',
#  'valeriestern_': 'role_0',
#  'vdB_Psychologie': 'role_7',
#  'ver_jorg': 'role_0',
#  'verenahubertz': 'role_0',
#  'verstand_clara': 'role_6',
#  'verusoss1': 'role_0',
#  'victorperli': 'role_4',
#  'viktor_victory': 'role_6',
#  'vinneyhouston': 'role_1',
#  'viola_kiel': 'role_0',
#  'viral_mobil': 'role_4',
#  'visionofsound': 'role_3',
#  'vitavonni': 'role_0',
#  'vmedick': 'role_0',
#  'vodionline': 'role_0',
#  'voglerk': 'role_4',
#  'volkerssohn': 'role_0',
#  'volkswagen': 'role_0',
#  'volmi6': 'role_0',
#  'vonDaeniken': 'role_0',
#  'vonDobrowolski': 'role_0',
#  'vonKleist87': 'role_3',
#  'von_Domatin': 'role_0',
#  'von_nicht': 'role_6',
#  'vonderleyen': 'role_0',
#  'vongizycki': 'role_0',
#  'vonundzupan': 'role_0',
#  'vorwaerts': 'role_1',
#  'vzhamburg': 'role_0',
#  'w1selly': 'role_3',
#  'w_schmidt': 'role_0',
#  'wagnmark': 'role_3',
#  'wahlforschung': 'role_3',
#  'walli5': 'role_3',
#  'walter_linke': 'role_0',
#  'walterweissenb5': 'role_3',
#  'wanderwitz': 'role_0',
#  'warumncht1': 'role_1',
#  'wathzmann': 'role_1',
#  'web_Theologie': 'role_0',
#  'webermannj': 'role_0',
#  'wegeheld': 'role_0',
#  'weiss_chr': 'role_6',
#  'wellcomeunited': 'role_0',
#  'wellsow': 'role_0',
#  'welt': 'role_0',
#  'weltsichten': 'role_0',
#  'welzi_original': 'role_5',
#  'wenkexin': 'role_0',
#  'wenzel_joachim': 'role_3',
#  'wernichtfragtb1': 'role_0',
#  'weserkurier': 'role_0',
#  'westfalenblatt': 'role_0',
#  'westphal': 'role_0',
#  'whitefury9': 'role_3',
#  'whitegandalf80': 'role_1',
#  'wibkegt': 'role_4',
#  'widderstand': 'role_6',
#  'wiebkewinter': 'role_0',
#  'willibald24': 'role_6',
#  'williehamburg': 'role_4',
#  'willy_wusel': 'role_0',
#  'witholli': 'role_4',
#  'wiwo': 'role_0',
#  'wldnsadb': 'role_6',
#  'wmr1704': 'role_6',
#  'woelfi69': 'role_3',
#  'woelken': 'role_4',
#  'wohooo_mp': 'role_6',
#  'wolke1231': 'role_3',
#  'worldsback2': 'role_0',
#  'worrius': 'role_7',
#  'wotanweiche': 'role_1',
#  'wuest23': 'role_6',
#  'wunder2welt': 'role_4',
#  'wupperdude': 'role_6',
#  'wurstmoped': 'role_6',
#  'wystrach': 'role_0',
#  'wznkm': 'role_4',
#  'xclsv3': 'role_0',
#  'xecon6': 'role_6',
#  'xeniaengel2020': 'role_0',
#  'xholonx': 'role_0',
#  'xileffff': 'role_0',
#  'xtp_official': 'role_3',
#  'y_marriex': 'role_5',
#  'yasminecmbarek': 'role_0',
#  'yello_de': 'role_0',
#  'ylvs': 'role_1',
#  'yogibaer02': 'role_6',
#  'yop_hans': 'role_0',
#  'yoschi147': 'role_1',
#  'yoxuxoy': 'role_6',
#  'yrthy': 'role_0',
#  'yvonnegoe1': 'role_4',
#  'zaubser': 'role_7',
#  'zebragrun': 'role_0',
#  'zeit_du': 'role_6',
#  'zeitonline': 'role_0',
#  'zeitonline_pol': 'role_0',
#  'zeleni_cz': 'role_0',
#  'zeuxis_cs': 'role_5',
#  'zooberlin': 'role_0',
#  'zukunftland': 'role_0',
#  'zvw_redaktion': 'role_0',
#  'zzurges': 'role_3'}
#
# Node role membership by percentage:
#                 role_0  role_1  role_2  role_3  role_4  role_5  role_6  role_7
# 00schneemann      0.12    0.12    0.12    0.12    0.12    0.12    0.12    0.12
# 0815_goes_4711    0.12    0.12    0.12    0.12    0.12    0.12    0.12    0.12
# 0Murat0           0.01    0.18    0.01    0.18    0.01    0.01    0.62    0.01
# 0__Punkt          0.12    0.12    0.12    0.12    0.12    0.12    0.12    0.12
# 0x127001          0.01    0.18    0.01    0.18    0.01    0.01    0.62    0.01
# ...                ...     ...     ...     ...     ...     ...     ...     ...
# zeuxis_cs         0.02    0.02    0.02    0.02    0.02    0.45    0.02    0.45
# zooberlin         0.12    0.12    0.12    0.12    0.12    0.12    0.12    0.12
# zukunftland       0.12    0.12    0.12    0.12    0.12    0.12    0.12    0.12
# zvw_redaktion     0.12    0.12    0.12    0.12    0.12    0.12    0.12    0.12
# zzurges           0.01    0.01    0.01    0.75    0.01    0.01    0.21    0.01
#
# [4114 rows x 8 columns]

# %%
#print list of usernames with specific role and add to a list

username_list = []
for username, role in node_roles.items():
    if role == 'role_7':
        username_list.append(username)

print(username_list)
# Out:
# ['1900HO', '90sChris', '98mercedes98', 'ARasilop', 'AWidmannMauz', 'AldousLeary', 'Alece92912603', 'Alexand36061482', 'AlexandraCarl2', 'AlpixTM', 'Amira_M_Ali', 'AnLa18294437', 'Andreas_Schwab', 'Anemalon19', 'Anja_aaaaa', 'ArneBab', 'AusBine', 'AxelHohl', 'BLN_CoMeCo', 'B_Gunners21', 'Ba5el', 'Bangeline6', 'Bennix1308', 'Bettina58130936', 'BobKelzow', 'Bode_Anne1', 'BoehningB', 'BreuerLeopold', 'BrunettiGi', 'CKross36', 'CMller3', 'Cardiesel2', 'Chris32770312', 'Chris__Tus', 'Christi43738671', 'ChristianDeut17', 'ChrizKu', 'Claudia2795', 'ClemensLeathley', 'Cochiban', 'Conni_Moehring', 'ConnyR0mer', 'Const99102', 'DanielaHuetter', 'Daniele95206428', 'DarioPower', 'Deliandelicious', 'Demetrio_Sca', 'DennisGladiator', 'DerKinderarzt', 'DerPrivatlehrer', 'Der_Bjoerni', 'Der_ToasterGmbh', 'Dericik76', 'DieterPrick', 'DoeSpam', 'Dorfblume1', 'DrCatlicious', 'DrHanisch', 'ElisabethKaleko', 'EnkelErich', 'Eric_mit_C', 'Erwin24946838', 'Estee77680659', 'EvAna3388', 'Eva0112', 'FKuschel', 'FReichert667', 'FirstGreenWave1', 'Flodine3', 'FoooBarBazz', 'Frank97078738', 'FrauDrAntiviral', 'FrauLalu', 'FredFlinkstone', 'GerhardRHuf', 'GiverSteve', 'GvB1480', 'HBahnmuller64', 'HannaSchfer3', 'HanneNagel1', 'HausnerPhilly', 'Heinzjean', 'Hermannsland1', 'HhYaus', 'HitOllga', 'HolgerEwald1', 'HolzwarthUwe', 'Hosenmaus1', 'IWillIlluminate', 'JSt04092834', 'Janine_Wissler', 'Jeniffe83264866', 'JohannesNormann', 'Just_Johannes', 'KEbnerSteiner', 'KaiBunchOfNo', 'KatharinaKoenig', 'Katinka1368', 'Katja84174609', 'KatjaMitteldorf', 'Katsanchebli', 'KerstinKopp7', 'KflexK', 'KimSieber4', 'KirstenTackmann', 'KokospalmeBlog', 'Kolibri32522549', 'LJohrendt', 'LandesMemeAnsta', 'Lasher67227061', 'LeibundgutEdith', 'Lena55856547', 'Lena_Star98', 'Lilablau23', 'Linke_Watch', 'Linksfraktion', 'LoeserKilian', 'LosLeventos', 'M10977012', 'MK27560487', 'MKies75', 'MM_Mbuna', 'MYkrzysztof', 'MacalaniaMagic', 'MagicSpaceBurns', 'MaikBeermann', 'Malte45293403', 'Marcus05911286', 'MarcusPretzell', 'MariaNoichl', 'MarioS94470956', 'MartinHaller', 'MartinSchaefer1', 'MatthiasHauer', 'Maxpower692', 'MdB_Schmidtke', 'MdB_Schreiber', 'MehlhornMartin', 'Meriptah', 'Michael_2305', 'MieruchMario', 'Minyas49866842', 'Mio84269003', 'Mueller1G', 'NaturBergmensch', 'Naturfreund_81', 'Nicole21249915', 'NiemaMovassat', 'NoraBless60', 'NuffSaid1922', 'OStraubing', 'Obg1887', 'OezlemADemirel', 'OlGr17', 'Oracle___', 'Phillip_Balt', 'PinioEl', 'PoehsesReich', 'Profe_Quiroga', 'Pterodactylus2', 'RadtkeMdEP', 'Raga123456890', 'RalfOffermann', 'Razzifazzi', 'RealKumberger', 'RebHarms', 'Regi88444401', 'RickJ78', 'Robbyx66', 'Robertf1964', 'RolandSB13', 'RonjaKemmer', 'RumblSixtyseven', 'Russels_Tea_Pot', 'SArina45130101', 'Sandra19870535', 'SaupreissDaniel', 'Schuster_MdEP', 'Seppel53718155', 'SoerenGruner', 'Sondergesandter', 'StefanGruhner', 'SteffiLemke', 'SteinMdL', 'Taifun987', 'Talena23472', 'ThStfu', 'Thomas_Bareiss', 'Tija74', 'TobiasEisenhut', 'TorstenFelsteha', 'TristanVeith', 'TschenPe', 'Ursel08151', 'UselmannM', 'Volli66093611', 'W_Schmidt_', 'YoMan32698435', 'ZDM09161302', 'ZaraRiffler', 'a_watch', 'abnonhar', 'ahmet6791035420', 'airbrushdesign', 'aminajxx', 'arMa_sN', 'aschalowski', 'atstp', 'baerbelbas', 'blenderbuch', 'bool1970', 'c_lindner', 'cem_oezdemir', 'corbaka', 'cordula62080696', 'coronaDystopia', 'correctiv_org', 'crypcoon', 'd0ink111', 'd4rkgrey', 'dannyfreymark', 'dazugeberin', 'dieLinke', 'druzim', 'dunklesritual', 'feliba54', 'fhoemcke', 'ggbh60', 'gunnar79106772', 'heschaus', 'hoentrop1965', 'i1m81', 'iPat69930566', 'ichbinsdieda', 'jankortemdb', 'jj_prinz', 'jounger', 'julia2809', 'justthore', 'kinderkongress', 'kira4990', 'kosmischkomisch', 'kumpernickel', 'larsklingbeil', 'lenavandijk', 'lgbeutin', 'liberte_b', 'lisapaus', 'mactr0n', 'markensysteme', 'mathiasrichel', 'mauricebmueller', 'mc_porsche', 'meridionale86', 'migi1002', 'mirjana_2011', 'mlorke1004', 'moritzkoerner', 'musikutiv', 'nhilsi', 'nurich08154711', 'offialkaren', 'otbhh', 'p_a_t_t_ ...

# %%
k = g.subgraph(username_list)

# %%
k

# %% [markdown]
# ### Role Extraction on Random Network

# %%
len(g)
# Out:
# 4114

# %%
h = nx.erdos_renyi_graph(100, 0.7)

# %%
h

# %%
# extract features
feature_extractor = RecursiveFeatureExtractor(h)
features = feature_extractor.extract_features()

# %%
# assign node roles
role_extractor = RoleExtractor(n_roles=None)
role_extractor.extract_role_factors(features)
node_roles = role_extractor.roles

print('\nnode_roles:')
pprint(node_roles)

print('\nNode role membership by percentage:')
print(role_extractor.role_percentage.round(2))
# Out:
# node_roles:
# {0: 'role_2',
#  1: 'role_4',
#  2: 'role_2',
#  3: 'role_2',
#  4: 'role_6',
#  5: 'role_2',
#  6: 'role_1',
#  7: 'role_2',
#  8: 'role_1',
#  9: 'role_4',
#  10: 'role_2',
#  11: 'role_2',
#  12: 'role_1',
#  13: 'role_2',
#  14: 'role_4',
#  15: 'role_6',
#  16: 'role_2',
#  17: 'role_2',
#  18: 'role_2',
#  19: 'role_1',
#  20: 'role_2',
#  21: 'role_2',
#  22: 'role_1',
#  23: 'role_1',
#  24: 'role_2',
#  25: 'role_2',
#  26: 'role_2',
#  27: 'role_2',
#  28: 'role_2',
#  29: 'role_2',
#  30: 'role_1',
#  31: 'role_2',
#  32: 'role_2',
#  33: 'role_4',
#  34: 'role_1',
#  35: 'role_1',
#  36: 'role_2',
#  37: 'role_2',
#  38: 'role_1',
#  39: 'role_1',
#  40: 'role_2',
#  41: 'role_1',
#  42: 'role_2',
#  43: 'role_4',
#  44: 'role_2',
#  45: 'role_2',
#  46: 'role_2',
#  47: 'role_1',
#  48: 'role_2',
#  49: 'role_2',
#  50: 'role_6',
#  51: 'role_2',
#  52: 'role_2',
#  53: 'role_2',
#  54: 'role_2',
#  55: 'role_1',
#  56: 'role_3',
#  57: 'role_2',
#  58: 'role_2',
#  59: 'role_2',
#  60: 'role_1',
#  61: 'role_1',
#  62: 'role_1',
#  63: 'role_1',
#  64: 'role_2',
#  65: 'role_2',
#  66: 'role_2',
#  67: 'role_1',
#  68: 'role_1',
#  69: 'role_2',
#  70: 'role_6',
#  71: 'role_2',
#  72: 'role_6',
#  73: 'role_2',
#  74: 'role_6',
#  75: 'role_4',
#  76: 'role_2',
#  77: 'role_0',
#  78: 'role_2',
#  79: 'role_6',
#  80: 'role_2',
#  81: 'role_4',
#  82: 'role_1',
#  83: 'role_2',
#  84: 'role_3',
#  85: 'role_1',
#  86: 'role_2',
#  87: 'role_2',
#  88: 'role_3',
#  89: 'role_6',
#  90: 'role_1',
#  91: 'role_6',
#  92: 'role_1',
#  93: 'role_2',
#  94: 'role_1',
#  95: 'role_3',
#  96: 'role_2',
#  97: 'role_2',
#  98: 'role_1',
#  99: 'role_6'}
#
# Node role membership by percentage:
#     role_0  role_1  role_2  role_3  role_4  role_5  role_6  role_7
# 0      0.0    0.26    0.37    0.00    0.18     0.0    0.18    0.00
# 1      0.0    0.00    0.00    0.00    0.49     0.0    0.49    0.00
# 2      0.0    0.26    0.37    0.00    0.18     0.0    0.18    0.00
# 3      0.0    0.00    0.48    0.00    0.25     0.0    0.25    0.00
# 4      0.0    0.00    0.00    0.22    0.22     0.0    0.32    0.22
# ..     ...     ...     ...     ...     ...     ...     ...     ...
# 95     0.0    0.00    0.00    0.33    0.33     0.0    0.33    0.00
# 96     0.0    0.00    0.57    0.20    0.00     0.0    0.00    0.20
# 97     0.0    0.00    0.52    0.00    0.27     0.0    0.00    0.19
# 98     0.0    0.56    0.00    0.42    0.00     0.0    0.00    0.00
# 99     0.0    0.00    0.00    0.42    0.00     0.0    0.56    0.00
#
# [100 rows x 8 columns]
